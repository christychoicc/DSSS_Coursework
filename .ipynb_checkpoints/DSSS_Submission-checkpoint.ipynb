# %% [markdown]
# # Pedestrian Collision Severity in London: Does Greenspace Accessibility Matter Beyond Collision and Casualty Factors?

# %% [markdown]
# ## Preface
#
# - GitHub Repository: [View link](https://github.com/christychoicc/DSSS_Coursework)
#
# - Number of words: ***
#
# - Runtime: *** hours (*Memory 10 GB, CPU Intel i7-10700 CPU @2.90GHz*)
#
# - Coding environment: SDS Docker (or anything else)
#
# - License: this notebook is made available under the [Creative Commons Attribution license](https://creativecommons.org/licenses/by/4.0/) (or other license that you like).
#
# - Additional library *[libraries not included in SDS Docker or not used in this module]*:
#     - **watermark**: A Jupyter Notebook extension for printing timestamps, version numbers, and hardware information.
#     - ......
#
# - Declaration: LLM is used for fixing coding and grammar mistakes.

# %% [markdown]
# ## Table of contents
#
# 1. [Introduction](#Introduction)
#
# 1. [Research questions](#Research-questions)
#
# 1. [Data](#Data)
#
# 1. [Methodology](#Methodology)
#
# 1. [Results and discussion](#Results-and-discussion)
#
# 1. [Conclusion](#Conclusion)
#
# 1. [References](#References)

# %% [markdown]
# ## 1. Introduction
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# Pedestrians are known as the most vulnerable road users, where they are more prone to higher injury severity levels in comparison to other road users (Pour-Rouholamin et.al., 2016). Reported by World Health Organisation (2023), more than half of global road traffic fatalities occur among vulnerable road users, including pedestrians. Pedestrian injury remains a key challenge for urban transport safety as pedestrians are more vulnerable to severe outcomes in road collisions events. While many road safety studies focus on traffic engineering and demographic factors, less attention has been given to whether neighbourhood environmental features such as if greenspace accessibility in promoting urban health. Under complex urban contexts, pedestrian collision severity may be shaped by a combination of road characteristics, traffic conditions, pedestrian characteristics, and wider environmental context. In London, the Mayor's Transport Strategy aims for a "Vision Zero" in eliminating all deaths and serious injuries from road collisions by 2041 (TfL, n.d.). The Vision Zero action plan also included a pedestrian target action for safer streets for walking and "transforming dangerous junctions" (TfL, n.d.).

# %% [markdown]
# **References**
#
# Pour-Rouholamin, M. and Zhou, H. (2016). Investigating the risk factors associated with pedestrian injury severity in Illinois. Journal of Safety Research, [online] 57, pp.9–17. doi:https://doi.org/10.1016/j.jsr.2016.03.004.
#
# World Health Organization (2023). Road traffic injuries. [online] World Health Organization. Available at: https://www.who.int/news-room/fact-sheets/detail/road-traffic-injuries.
#
# ‌TfL (n.d.). Vision Zero for London. [online] Available at: https://tfl.gov.uk/corporate/protecting-our-network/road-safety/vision-zero-for-london
# ‌

# %% [markdown]
# ## 2. Research Question
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# Pedestrian safety is a major urban policy and public health concern because severe pedestrian injuries reflect not only traffic conditions, but also the interaction between road design, pedestrian behaviour, environmental context, and neighbourhood characteristics. This study focuses on pedestrian-involved collisions in London and examines whether urban greenspace accessibility contributes meaningful explanatory value beyond established collision and casualty factors. Therefore, this analysis aims to answer the following research questions:
#
# **RQ1** - Which factors most influences most in the prediction of fatal or serious pedestrian injuries in London in 2024?
#
# **RQ2** - Does proximity to urban greenspace access points add meaningful explanatory power for predicting pedestrian injury severity, after accounting for casualty, collision, and road environment characteristics?

# %% [markdown]
# ## 3. Data
#
# [[ go back to the top ]](#Table-of-contents)
#
# In this section, relevant datasets are pre-processed, cleaned, and spatially linked to construct a London pedestrian collision dataframe. Second, descriptive and spatial exploratory analysis is used to examine the distribution of severe outcomes and greenspace accessibility. Third, the prepared analytical dataset is used for later model-based analysis to assess whether greenspace accessibility remains relevant after accounting for other factors.

# %% [markdown]
# ### 3.1. Data Evaluation
#
# #### Data Sources:
# This analysis uses the following datasets:
#
# 1. **[Road Safety Collision data (2024)](https://www.gov.uk/government/statistical-data-sets/road-safety-open-data)**
#    This dataset contains collision-level information including location, road characteristics, environmental conditions, and counts of vehicles and casualties.
#
# 2. **[Road Safety Casualty data (2024)](https://www.gov.uk/government/statistical-data-sets/road-safety-open-data)**
#    This dataset contains casualty-level information including casualty severity, pedestrian movement, pedestrian location, age, sex, and area-level deprivation indicators.
#
# 3. **[Road Safety Vehicle data (2024)](https://www.gov.uk/government/statistical-data-sets/road-safety-open-data)**
#
# 4. **[OS Open Greenspace Access Point data](https://osdatahub.os.uk/data/downloads/open/OpenGreenspace?_gl=1*lcmfh4*_ga*ODk4MTE3Nzk4LjE3NzU1ODM0ODg.*_ga_59ZBN7DVBG*czE3NzU1ODM0ODckbzEkZzAkdDE3NzU1ODM2NDgkajYwJGwwJGgw)**
#
# 5. **[London LSOA boundary data](https://data.london.gov.uk/dataset/statistical-gis-boundary-files-for-london-20od9/)**
#    This dataset is used for spatial filtering to study area, mapping purposes.
#
# #### Data Limitations
# There are two main data limitations in the road safety datasets that may impact the analytical scope of this study. The open release excludes the contributory factors table, which captures officer-recorded behavioural causes of collisions such as driver inattention, failure to observe, or excessive speed. Research has demonstrated that incorporating these variables substantially improves the predictive performance of injury severity models, and their absence from the open release on privacy grounds places a ceiling on what can reasonably be achieved from open data alone. Additionally, UK police forces began transitioning from officer-assessed to injury-based severity recording from 2016 onwards. Although this study is restricted to London collisions in 2024, the possibility that residual inconsistency in severity classification introduces noise into the target variable cannot be fully discounted and is acknowledged as a limitation of the underlying data.

# %% [markdown]
# ### 3.2. Load Packages
# The below shows packages to install and import for data pre-processing, manipulation and running the analysis:

# %%
# Packages to install first prior to importing
#%pip install shap

# %%
# Packages for data processing and analysis

# --------------------------------- Data Wrangling and EDA -----------------------------------
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

import warnings
warnings.filterwarnings('ignore')

# ------------------------------------ Preprocessing --------------------------------------
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# ------------------------------------ Model Selection --------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# ------------------------------------ Machine Learning --------------------------------------
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import SelectFromModel

# ----------------------------------- Accuracy Assessment -------------------------------------
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report,
    roc_auc_score, average_precision_score,
    ConfusionMatrixDisplay, PrecisionRecallDisplay, RocCurveDisplay
)

# ----------------------------------- Model Interpretation -------------------------------------
import shap

# %% [markdown]
# ### 3.3. Data Loading

# %%
# Load Collision 2024
collision = pd.read_csv("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/dft-road-casualty-statistics-collision-2024.csv", low_memory=False)

# Load Casualty 2024 
casualty = pd.read_csv("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/dft-road-casualty-statistics-casualty-2024.csv", low_memory=False)

# Load Casualty 2024 
vehicle = pd.read_csv("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/dft-road-casualty-statistics-vehicle-2024.csv", low_memory=False)

# Load Green Space data
greenspace = gpd.read_file("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/OS-Open-Greenspace-GB/GB_AccessPoint.shp")

# Load London LOSA boundary data
london_lsoa = gpd.read_file("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/london_LSOA_boundary/LSOA_2011_London_gen_MHW.shp")

# Standardise column names
collision.columns = collision.columns.str.strip().str.lower()
casualty.columns  = casualty.columns.str.strip().str.lower()
vehicle.columns   = vehicle.columns.str.strip().str.lower()
greenspace.columns = greenspace.columns.str.strip().str.lower()

# %%
# Data Inspection

# Inspect number of rows and columns for all dataset
print("Collision data shape:", collision.shape)
print("Casualty data shape:", casualty.shape)
print("Vehicle data shape:", vehicle.shape)
# print("Greenspace data shape:", greenspace.shape)
# print("London LSOA shape:", london_lsoa.shape)

# Inspect CRS for greenspace and London boundary data
print("\nGreenspace CRS:", greenspace.crs)
print("London LSOA CRS:", london_lsoa.crs)

# Inspect column names for all dataset
print("\nCollision Column names:")
print(collision.columns.tolist())
print("\nCasualty Column names:")
print(casualty.columns.tolist())
print("\nVehicle Column names:")
print(vehicle.columns.tolist())
print("\nGreenspace Column names:")
print(greenspace.columns.tolist())
# Out:
# Collision data shape: (100927, 44)
# Casualty data shape: (128272, 23)
# Vehicle data shape: (183514, 32)
#
# Greenspace CRS: EPSG:27700
# London LSOA CRS: PROJCS["OSGB36 / British National Grid",GEOGCS["OSGB36",DATUM["Ordnance_Survey_of_Great_Britain_1936",SPHEROID["Airy 1830",6377563.396,299.3249646,AUTHORITY["EPSG","7001"]],AUTHORITY["EPSG","6277"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",49],PARAMETER["central_meridian",-2],PARAMETER["scale_factor",0.999601272],PARAMETER["false_easting",400000],PARAMETER["false_northing",-100000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#
# Collision Column names:
# ['collision_index', 'collision_year', 'collision_ref_no', 'location_easting_osgr', 'location_northing_osgr', 'longitude', 'latitude', 'police_force', 'collision_severity', 'number_of_vehicles', 'number_of_casualties', 'date', 'day_of_week', 'time', 'local_authority_district', 'local_authority_ons_district', 'local_authority_highway', 'local_authority_highway_current', 'first_road_class', 'first_road_number', 'road_type', 'speed_limit', 'junction_detail_historic', 'junction_detail', 'junction_control', 'second_road_class', 'second_road_number', 'pedestrian_crossing_human_control_historic', 'pedestrian_crossing_physical_facilities_historic', 'pedestrian_crossing', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'special_conditions_at_site', 'carriageway_hazards_historic', 'carriageway_hazards', 'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident', 'trunk_road_flag', 'lsoa_of_accident_location', 'enhanced_severity_collision', 'collision_injury_based', 'collision_adjusted_severity_serious', 'collision_adjusted_severity_slight']
#
# Casualty Column names:
# ['collision_index', 'collision_year', 'collision_ref_no', 'vehicle_reference', 'casualty_reference', 'casualty_class', 'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty', 'casualty_severity', 'pedestrian_location', 'pedestrian_movement', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_imd_decile', 'lsoa_of_casualty', 'enhanced_casualty_severity', 'casualty_injury_based', 'casualty_adjusted_severity_serious', 'casualty_adjusted_severity_slight', 'casualty_distance_banding']
#
# Vehicle Column names:
# ['collision_index', 'collision_year', 'collision_ref_no', 'vehicle_reference', 'vehicle_type', 'towing_and_articulation', 'vehicle_manoeuvre_historic', 'vehicle_manoeuvre', 'vehicle_direction_from', 'vehicle_direction_to', 'vehicle_location_restricted_lane_historic', 'vehicle_location_restricted_lane', 'junction_location', 'skidding_and_overturning', 'hit_object_in_carriageway', 'vehicle_leaving_carriageway', 'hit_object_off_carriageway', 'first_point_of_impact', 'vehicle_left_hand_drive', 'journey_purpose_of_driver_historic', 'journey_purpose_of_driver', 'sex_of_driver', 'age_of_driver', 'age_band_of_driver', 'engine_capacity_cc', 'propulsion_code', 'age_of_vehicle', 'generic_make_model', 'driver_imd_decile', 'lsoa_of_driver', 'escooter_flag', 'driver_distance_banding']
#
# Greenspace Column names:
# ['id', 'accesstype', 'reftogsite', 'geometry']

# %% [markdown]
# ### 3.4. Data Pre-processing

# %% [markdown]
# #### 3.4.1. Data Cleaning

# %%
# Filter to London collisions only
collision_london = collision[
    collision['local_authority_ons_district'].astype(str).str.startswith('E09')
].copy()

print("London collisions shape:", collision_london.shape)
print(collision_london['local_authority_ons_district'].nunique())
# Out:
# London collisions shape: (20967, 44)
# 33

# %%
# Filter Greenspace data to London only
london_boundary = london_lsoa.dissolve()
# Ensure consistent CRS
greenspace = greenspace.to_crs(london_boundary.crs)
# Clip greenspace to the exact London boundary
greenspace_london = gpd.clip(greenspace, london_boundary)


# Transform geometry column's point(x y z) into normal point(x y) only
# Code provided from LLM (Claude AI)
greenspace_london['geometry'] = greenspace_london['geometry'].apply(
    lambda g: Point(g.x, g.y)  # drops Z, keeps X and Y only
)

# Create collision points for nearest greenspace distance
collision_points = gpd.GeoDataFrame(
    # remove duplicated collision_index
    collision_london[['collision_index', 'longitude', 'latitude']].dropna().drop_duplicates('collision_index'),
    # convert lat and long to geometry
    geometry=gpd.points_from_xy(
        collision_london[['collision_index', 'longitude', 'latitude']].dropna().drop_duplicates('collision_index')['longitude'],
        collision_london[['collision_index', 'longitude', 'latitude']].dropna().drop_duplicates('collision_index')['latitude']
    ),
    crs='EPSG:4326'
).to_crs('EPSG:27700')

# Nearest greenspace access p
collision_green_nearest = gpd.sjoin_nearest(
    collision_points,
    greenspace_london[['geometry']],
    how='left',
    distance_col='dist_to_greenspace_m'
)[['collision_index', 'dist_to_greenspace_m']].drop_duplicates('collision_index')

# Merge newly computed collisioin to nearest greenspace a.p. with london collision
collision_london = collision_london.merge(
    collision_green_nearest,
    on='collision_index',
    how='left'
)

# %%
# Check new column data
print(collision_london[['dist_to_greenspace_m']].describe())
# Out:
#        dist_to_greenspace_m
# count          20967.000000
# mean             168.967535
# std              130.287320
# min                1.332926
# 25%               80.158523
# 50%              143.163959
# 75%              226.745816
# max             1924.209747

# %%
# Filter to Pedestrian casualties only
# 3 = Pedestrians
casualty_ped = casualty[casualty['casualty_class'] == 3].copy()
print(casualty_ped['casualty_class'].value_counts(dropna=False))
# Out:
# Pedestrian casualties shape: (19176, 23)
# casualty_class
# 3    19176
# Name: count, dtype: int64

# %%
# Filter for London Pedestrian casualties only
casualty_ped_london = casualty_ped[
    casualty_ped['collision_index'].isin(collision_london['collision_index'])
].copy()

print("London pedestrian casualties shape:", casualty_ped_london.shape)
# Out:
# London pedestrian casualties shape: (4445, 23)

# %% [markdown]
# #### 3.4.2. Data Joins/ Merge

# %%
# Merge collision and casualty data on collision_index
merge = casualty_ped_london.merge(
    # drop duplicate columns for merge
    collision_london.drop(columns=['collision_year', 'collision_ref_no'], errors='ignore'),
    on='collision_index',
    how='left'
)

print("After collision casualty merge:", merge.shape)
# Out:
# After collision casualty merge: (4445, 65)

# %%
# Merge collision and casualty data with vehicle data
vehicle_merge = vehicle.drop(
    # drop duplicate columns for merge
    columns=['collision_year', 'collision_ref_no'],
    errors='ignore'
)

# Merge
merge2 = merge.merge(
    vehicle_merge,
    on=['collision_index', 'vehicle_reference'],
    how='left'
)

# Check merged data shape
print("After vehicle merge:", merge2.shape)
# Out:
# After vehicle merge: (4445, 95)

# %% [markdown]
# #### 3.4.3. Data Ambiguity (Missing, Unknown, Undefined, Others)

# %% [markdown]
# Variables coded for missing, unknown or other values were found present within the dataset. To solve the data ambiguity, these values were recoded to `NaN` so that they will be treated as missing data instead of real values. Missing numeric values will be imputed with a median value, and missing categorical values will be replaced with a "Missing" category.
#
# |Variable|Code|Code Interpretation|Action|
# |---|---|---|---|
# |speed_limit|-1, 99|Missing / unknown|Recode to `NaN`, later impute as categorical `Missing`|
# |junction_detail|-1, 99|Missing / unknown|Recode to `NaN`, later impute as categorical `Missing`|
# |junction_control|-1, 9|Missing / unknown|Recode to `NaN`, later impute as categorical `Missing`|
# |pedestrian_crossing|-1, 99|Missing / unknown|Recode to `NaN`, later impute as categorical `Missing`|
# |light_conditions|-1|Missing|Recode to `NaN`, later impute as categorical `Missing`|
# |weather_conditions|-1, 9|Missing / unknown|Recode to `NaN`; `8 = Other` retained|
# |road_surface_conditions|-1, 9|Missing / unknown|Recode to `NaN`, later impute as categorical `Missing`|
# |urban_or_rural_area |-1, 3|Missing / unallocated|Recode to `NaN`, later impute as categorical `Missing`|
# |sex_of_casualty |-1, 9|Missing / unknown|Recode to `NaN`, later impute as categorical `Missing`|
# |age_of_casualty |-1|Missing|Recode to `NaN`, later impute using median|
# |age_band_of_casualty|-1|Missing|Recode to `NaN`|
# |pedestrian_location|-1|Missing|Recode to `NaN`; other valid location codes retained|
# |pedestrian_movement|-1|Missing|Recoded to `NaN`; other valid movement codes retained|
# |pedestrian_road_maintenance_worker|-1, 2|Missing / not known|Recode to `NaN`, later impute as categorical `Missing`|
# |casualty_imd_decile|-1|Missing|Recode to `NaN`, later impute as categorical `Missing`|
# |vehicle_type|-1|Missing|Recode to `NaN`; valid code `90 = Other vehicle` retained|
# |vehicle_manoeuvre|-1, 99|Missing / unknown|Recode to `NaN`, later impute as categorical `Missing`|
# |sex_of_driver|-1, 3|Missing / not known|Recode to `NaN`, later impute as categorical `Missing`|
# |age_of_driver|-1|Missing|Recode to `NaN`, later impute using median|
# |age_band_of_driver|-1|Missing|Recode to `NaN`|
# |propulsion_code|-1|Missing|Recode to `NaN`; later exclude from modelling due to high missingness|

# %%
# Variable-specific recoding rules
recode_nan = {
    # collision
    'speed_limit': [-1, 99],
    'junction_detail': [-1, 99],
    'junction_control': [-1, 9],
    'pedestrian_crossing': [-1, 99],
    'light_conditions': [-1],
    'weather_conditions': [-1, 9],   # keep 8 = Other
    'road_surface_conditions': [-1, 9],
    'urban_or_rural_area': [-1, 3],  # 3 = Unallocated

    # casualty
    'sex_of_casualty': [-1, 9],
    'age_of_casualty': [-1],
    'age_band_of_casualty': [-1],
    'pedestrian_location': [-1],     # keep 10 for now
    'pedestrian_movement': [-1],     # keep 9 for now
    'pedestrian_road_maintenance_worker': [-1, 2],  # 2 = Not Known
    'casualty_imd_decile': [-1],

    # vehicle
    'vehicle_type': [-1],            # keep 90 = Other vehicle
    'vehicle_manoeuvre': [-1, 99],
    'sex_of_driver': [-1, 3],        # 3 = Not known
    'age_of_driver': [-1],
    'age_band_of_driver': [-1],
    'propulsion_code': [-1]
}

# %%
# Set recode function
def apply_recode(df, recode_dict):
    df = df.copy()
    for col, bad_codes in recode_dict.items():
        if col in df.columns:
            df[col] = df[col].replace(bad_codes, np.nan)
    return df

# %%
# Apply recode functions to the merged dataset
merged = apply_recode(merge2, recode_nan)
print("Merged and recoded clean study dataset shape:", merged.shape)
# Out:
# Merged and recoded clean study dataset shape: (4445, 95)

# %%
print("\n Merged Dataframe Columns:")
print(merged.columns.tolist())
# Out:
#  Merged Dataframe Columns:
# ['collision_index', 'collision_year_cas', 'collision_ref_no_cas', 'vehicle_reference', 'casualty_reference', 'casualty_class', 'sex_of_casualty', 'age_of_casualty', 'age_band_of_casualty', 'casualty_severity', 'pedestrian_location', 'pedestrian_movement', 'car_passenger', 'bus_or_coach_passenger', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_imd_decile', 'lsoa_of_casualty', 'enhanced_casualty_severity', 'casualty_injury_based', 'casualty_adjusted_severity_serious', 'casualty_adjusted_severity_slight', 'casualty_distance_banding', 'collision_year_col', 'collision_ref_no_col', 'location_easting_osgr', 'location_northing_osgr', 'longitude', 'latitude', 'police_force', 'collision_severity', 'number_of_vehicles', 'number_of_casualties', 'date', 'day_of_week', 'time', 'local_authority_district', 'local_authority_ons_district', 'local_authority_highway', 'local_authority_highway_current', 'first_road_class', 'first_road_number', 'road_type', 'speed_limit', 'junction_detail_historic', 'junction_detail', 'junction_control', 'second_road_class', 'second_road_number', 'pedestrian_crossing_human_control_historic', 'pedestrian_crossing_physical_facilities_historic', 'pedestrian_crossing', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'special_conditions_at_site', 'carriageway_hazards_historic', 'carriageway_hazards', 'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident', 'trunk_road_flag', 'lsoa_of_accident_location', 'enhanced_severity_collision', 'collision_injury_based', 'collision_adjusted_severity_serious', 'collision_adjusted_severity_slight', 'dist_to_greenspace_m', 'vehicle_type', 'towing_and_articulation', 'vehicle_manoeuvre_historic', 'vehicle_manoeuvre', 'vehicle_direction_from', 'vehicle_direction_to', 'vehicle_location_restricted_lane_historic', 'vehicle_location_restricted_lane', 'junction_location', 'skidding_and_overturning', 'hit_object_in_carriageway', 'vehicle_leaving_carriageway', 'hit_object_off_carriageway', 'first_point_of_impact', 'vehicle_left_hand_drive', 'journey_purpose_of_driver_historic', 'journey_purpose_of_driver', 'sex_of_driver', 'age_of_driver', 'age_band_of_driver', 'engine_capacity_cc', 'propulsion_code', 'age_of_vehicle', 'generic_make_model', 'driver_imd_decile', 'lsoa_of_driver', 'escooter_flag', 'driver_distance_banding']

# %% [markdown]
# #### 3.4.4. Data Filtering

# %%
# Select needed columns
selected_columns = [
    # target
    'casualty_severity',

    # casualty, pedestrian variables
    'sex_of_casualty',
    'age_of_casualty',
    'pedestrian_location',
    'pedestrian_movement',
    'pedestrian_road_maintenance_worker',
    'casualty_type',
    'casualty_imd_decile',
    'lsoa_of_accident_location',

    # collision, road and environment variables
    'longitude',
    'latitude',
    'day_of_week',
    'time',
    'speed_limit',
    'first_road_class',
    'road_type',
    'junction_detail',
    'junction_control',
    'pedestrian_crossing',
    'light_conditions',
    'weather_conditions',
    'road_surface_conditions',
    'number_of_vehicles',
    'urban_or_rural_area',
    'trunk_road_flag',

    # vehicle, driver variables
    'vehicle_type',
    'vehicle_manoeuvre',
    'junction_location',
    'sex_of_driver',
    'age_of_driver',
    'propulsion_code',
    'age_of_vehicle',
    'engine_capacity_cc',
    'driver_imd_decile',
    'escooter_flag',

     # spatial contextual variable
    'dist_to_greenspace_m'
]

selected_columns = [c for c in selected_columns if c in merged.columns]

df_clean = merged[selected_columns].copy()

print("Selected dataset shape:", df_clean.shape)
print(df_clean.columns.tolist())
# Out:
# Selected dataset shape: (4445, 36)
# ['casualty_severity', 'sex_of_casualty', 'age_of_casualty', 'pedestrian_location', 'pedestrian_movement', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_imd_decile', 'lsoa_of_accident_location', 'longitude', 'latitude', 'day_of_week', 'time', 'speed_limit', 'first_road_class', 'road_type', 'junction_detail', 'junction_control', 'pedestrian_crossing', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'number_of_vehicles', 'urban_or_rural_area', 'trunk_road_flag', 'vehicle_type', 'vehicle_manoeuvre', 'junction_location', 'sex_of_driver', 'age_of_driver', 'propulsion_code', 'age_of_vehicle', 'engine_capacity_cc', 'driver_imd_decile', 'escooter_flag', 'dist_to_greenspace_m']

# %% [markdown]
# #### 3.4.5. Data Wrangling

# %% [markdown]
# The severity levels variable is defined as:
#
# - **1 = fatal or serious pedestrian outcome**
# - **0 = slight pedestrian outcome**
#
# The analysis is conducted at the pedestrian casualty level, meaning that each row in the analytical dataset represents one pedestrian casualty involved in a road collision in London in 2024. A pedestrian casualty is encoded as 1 if their recorded injury severity is fatal or serious, and as 0 if it is slight. As the analysis is conducted at the pedestrian casualty level, some collisions may contribute more than one pedestrian collision event where multiple pedestrians injuries were involved. This is acknowledged as a limitation, as observations from the same collision event may not be entirely independent.

# %%
# Create a binary for our target (severity levels)
df_clean['severity_levels'] = np.where(df_clean['casualty_severity'].isin([1, 2]), 1, 0)

print(df_clean['severity_levels'].value_counts())
# Out:
# severity_levels
# 0    3249
# 1    1196
# Name: count, dtype: int64

# %%
# Convert time to datetime and extract hour
df_clean['time'] = pd.to_datetime(df_clean['time'], format='%H:%M', errors='coerce')
df_clean['hour'] = df_clean['time'].dt.hour

# %%
# Drop propulsion_code (cus found to have 1906 missing rows)
df_clean = df_clean.drop(columns=['propulsion_code'], errors='ignore')

# %%
# Define features
numeric_features = [
    'age_of_casualty',
    'longitude',
    'latitude',
    'number_of_vehicles',
    'age_of_driver',
    'age_of_vehicle',
    'engine_capacity_cc',
    'hour',
    'dist_to_greenspace_m'
]
categorical_features = [
    'sex_of_casualty',
    'pedestrian_location',
    'pedestrian_movement',
    'pedestrian_road_maintenance_worker',
    'casualty_type',
    'casualty_imd_decile',
    'day_of_week',
    'speed_limit',
    'first_road_class',
    'road_type',
    'junction_detail',
    'junction_control',
    'pedestrian_crossing',
    'light_conditions',
    'weather_conditions',
    'road_surface_conditions',
    'urban_or_rural_area',
    'trunk_road_flag',
    'vehicle_type',
    'vehicle_manoeuvre',
    'junction_location',
    'sex_of_driver',
    'driver_imd_decile',
    'escooter_flag'
]

# %%
# Assign categroical features as objects (aka categories make them not comparable numbers)
# Numeric columns: keep numeric
for col in numeric_features:
    if col in df_clean.columns:
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')

# Categorical columns: convert all non-missing values to strings, keep missing as np.nan
for col in categorical_features:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].apply(lambda x: np.nan if pd.isna(x) else str(x))

# %%
print("Wrangled dataset shape:", df_clean.shape)
print(df_clean.columns.tolist())
# Out:
# Wrangled dataset shape: (4445, 37)
# ['casualty_severity', 'sex_of_casualty', 'age_of_casualty', 'pedestrian_location', 'pedestrian_movement', 'pedestrian_road_maintenance_worker', 'casualty_type', 'casualty_imd_decile', 'lsoa_of_accident_location', 'longitude', 'latitude', 'day_of_week', 'time', 'speed_limit', 'first_road_class', 'road_type', 'junction_detail', 'junction_control', 'pedestrian_crossing', 'light_conditions', 'weather_conditions', 'road_surface_conditions', 'number_of_vehicles', 'urban_or_rural_area', 'trunk_road_flag', 'vehicle_type', 'vehicle_manoeuvre', 'junction_location', 'sex_of_driver', 'age_of_driver', 'age_of_vehicle', 'engine_capacity_cc', 'driver_imd_decile', 'escooter_flag', 'dist_to_greenspace_m', 'severity_levels', 'hour']

# %% [markdown]
# #### 3.4.6. Impute missing values before machine learning
# A pre-processing pipeline is used to prepare predictors for modelling. Numeric variables were imputed using the median and standardised, while categorical variables were imputed with a "Missing" category and one-hot encoded. A ColumnTransformer was used to allow application of different pre-processing workflow to different columns within the machine learning pipeline.

# %%
# Impute as Tree based methods cannot deal with NaNs
# Impute NaN with median
numeric_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Impute NaN with 'Missing'
categorical_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

transformed = ColumnTransformer(
    transformers=[
        # numeric
        ('num', numeric_pipeline, numeric_features),
        # categorical
        ('cat', categorical_pipeline, categorical_features)
    ]
)

# %% [markdown]
# #### 3.4.7. Variables after Data Cleaning
# ##### 3.4.7.1. Metadata
# The cleaned dataframe was retained in its original variable structure for documentation and interpretation. Additional preprocessing for tree-based methods analysis, including imputation, scaling, and one-hot encoding, was applied later within the modelling pipeline and will not alter the structure of the cleaned dataframe.
# | Variable Name | Description | Data Type | Purpose |
# |---|---|---|---|
# | severity_levels | Binary pedestrian injury outcome: 1 = fatal or serious injury, 0 = slight injury | Binary | Target |
# | casualty_severity | Original recorded casualty severity from the road safety dataset | Categorical | Used to create severity_levels (above) |
# | sex_of_casualty | Sex of the pedestrian casualty | Categorical | Predictor |
# | age_of_casualty | Age of the pedestrian casualty in years | Numeric | Predictor |
# | pedestrian_location | Pedestrian’s location relative to the carriageway or crossing at the time of collision | Categorical | Predictor |
# | pedestrian_movement | Reported movement of the pedestrian at the time of collision | Categorical | Predictor |
# | pedestrian_road_maintenance_worker | Whether the pedestrian was recorded as a road maintenance worker | Categorical | Predictor |
# | casualty_type | Type of casualty involved in the collision | Categorical | Predictor |
# | casualty_imd_decile | Index of Multiple Deprivation decile associated with the casualty area | Categorical | Predictor |
# | lsoa_of_accident_location | LSOA code of the collision location | ID  | Used for Spatial Aggreation for Exploratory Analysis |
# | longitude | Longitude coordinate of the collision location | Numeric | Spatial Predictor|
# | latitude| Latitude coordinate of the collision location | Numeric | Spatial Predictor  |
# |day_of_week | Day of the week on which the collision occurred | Categorical | Predictor |
# | time | Recorded time of collision | Time | Calculate `hour` for Prediction |
# | hour | Hour of day extracted from collision time | Numeric | Predictor |
# | speed_limit | Posted speed limit at the collision location | Categorical | Predictor |
# | first_road_class | Class of the first road at the collision location | Categorical | Predictor |
# | road_type | Type of road where the collision occurred | Categorical | Predictor |
# | junction_detail | Type of junction at the collision location | Categorical | Predictor |
# | junction_control | Traffic control present at the junction | Categorical | Predictor |
# | pedestrian_crossing | Type of pedestrian crossing facility present | Categorical | Predictor |
# | light_conditions | Lighting conditions at the time of collision | Categorical | Predictor |
# | weather_conditions | Weather conditions at the time of collision | Categorical | Predictor |
# | road_surface_conditions | Condition of the road surface at the time of collision | Categorical | Predictor |
# | number_of_vehicles | Number of vehicles involved in the collision | Numeric | Predictor |
# | urban_or_rural_area | Classification of the collision location as urban or rural | Categorical | Predictor |
# | trunk_road_flag | Indicator of whether the collision occurred on a trunk road | Categorical | Predictor |
# | vehicle_type | Type of vehicle associated with the pedestrian casualty | Categorical | Predictor |
# | vehicle_manoeuvre | Manoeuvre of the associated vehicle at the time of collision | Categorical | Predictor |
# | junction_location | Position of the associated vehicle relative to the junction | Categorical | Predictor |
# | sex_of_driver | Sex of the associated driver | Categorical | Predictor |
# | age_of_driver | Age of the associated driver in years | Numeric | Predictor |
# | age_of_vehicle | Age of the associated vehicle in years | Numeric | Predictor |
# | engine_capacity_cc | Engine capacity of the associated vehicle in cubic centimetres | Numeric | Predictor |
# | driver_imd_decile | Index of Multiple Deprivation decile associated with the driver area | Categorical | Predictor |
# | escooter_flag | Indicator of associated vehicle as e-scooter | Categorical | Predictor |
#
# ##### 3.4.7.2. Data Categorisation
# - **Target variable**: pedestrian injury severity (`severity_levels`), derived from the original recorded casualty severity.
# - **Pedestrian Characteristics**: attributes describing pedestrian casualty, including age, sex, movement, location, road maintenance status, casualty type, and deprivation decile, etc.
# - **Road Environment**: variables describing the road setting, junction context, pedestrian crossing, speed limit, lighting, weather, road surface condition, and number of vehicles involved, etc.
# - **Vehicle and Driver Characteristics**: attributes of the associated vehicle and driver, including vehicle type, manoeuvre, junction position, driver sex, driver age, vehicle age, engine capacity, deprivation decile, etc.

# %% [markdown]
# ## 4. Methodology
#
# [[ go back to the top ]](#Table-of-contents)
#
# This section will apply two tree-based classification methods, Decision Tree as a baseline model and Random Forest as the main model to predict fatal or serious pedestrian injury outcomes in London road collisions and identify factors that contribute most to injury severity.
#
# ### Methodological Challenges
# A structural challenge common to road collision datasets is class imbalance. In this analytical sample, fatal and serious casualties account for approximately 26.9% of observations, with slight injuries comprising the remaining 73.1%. An unweighted classifier trained on this data would be biased toward predicting the majority class, which will result will poorly perform on the events for greatest safety relevance. To address this, class weighting was applied in both models, assigning a higher penalty to misclassification of the minority fatal/serious class.
# Recall was therefore prioritised as the primary evaluation metric over accuracy. In a road safety context, failing to identify a genuinely severe outcome carries a greater real-world cost than generating a false positive, a model that misses fatal collisions is more dangerous than one that occasionally over-predicts severity.
#
# ### Model and Model Interpretation
# A Decision Tree was used as a baseline model. A Random Forest was then applied as the primary model, as ensemble methods are generally more robust to overfitting. SHAP values were used to interpret the Random Forest, quantifying each variable's contribution to model's predictions.
#
# ### 4.1. Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

severity_counts = df_clean['severity_levels'].value_counts()
labels = ['Slight (0)', 'Fatal/Serious (1)']
colors = ['#2B6CB0', '#C81E2A']

fig, ax = plt.subplots(figsize=(6, 4))
bars = ax.bar(labels, severity_counts.values, color=colors, edgecolor='white', width=0.5)

for bar, count in zip(bars, severity_counts.values):
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() + 30,
            f'{count}\n({count/len(df_clean)*100:.1f}%)',
            ha='center', va='bottom', fontsize=11)

ax.set_title('Distribution of Pedestrian Injury Severity', fontsize=13)
ax.set_ylabel('Number of Casualties')
ax.set_ylim(0, severity_counts.max() * 1.2)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))

for level, label, color in zip([0, 1], ['Slight', 'Fatal/Serious'], ['#2B6CB0', '#C81E2A']):
    subset = df_clean[df_clean['severity_levels'] == level]['dist_to_greenspace_m'].dropna()
    ax.hist(subset, bins=30, alpha=0.6, label=label, color=color, edgecolor='white', density=True)

ax.set_title('Distance to Nearest Greenspace by Severity Level', fontsize=13)
ax.set_xlabel('Distance to Greenspace')
ax.set_ylabel('Density')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# This figure shows that the distribution of distance to the nearest greenspace access point is broadly similar across the two severity levels, with both distributions peaking between 100–150m and declining at greater distances. This suggests that greenspace proximity alone may not strongly distinguish between slight and fatal/serious pedestrian casualties."

# %%
fig, ax = plt.subplots(figsize=(6, 4))

data_age = [
    df_clean[df_clean['severity_levels'] == 0]['age_of_casualty'].dropna(),
    df_clean[df_clean['severity_levels'] == 1]['age_of_casualty'].dropna()
]
ax.boxplot(data_age, labels=['Slight', 'Fatal/Serious'],
           patch_artist=True,
           boxprops=dict(facecolor='#D0E8FF', color='#4A90D9'),
           medianprops=dict(color='#E05C5C', linewidth=2))
ax.set_title('Age of Pedestrian Casualty by Injury Severity', fontsize=13, fontweight='bold')
ax.set_ylabel('Age (years)')
plt.tight_layout()
plt.show()s

# %% [markdown]
# ### 4.2. Decision Tree

# %%
X = df_clean[numeric_features + categorical_features].copy()
y = df_clean['severity_levels'].copy()

X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval,
    test_size=0.25,   # 25% of 80% = 20% validation
    random_state=42,
    stratify=y_trainval
)

# %%
# Decision Tree pipeline
dt_pipeline = Pipeline(steps=[
    ('transformed', transformed),
    ('model', DecisionTreeClassifier(random_state=42))
])

# Grid
param_grid_dt = {
    'model__max_depth': [3, 5, 10, 15, 20, None],
    'model__min_samples_split': [5, 10, 20],
    'model__min_samples_leaf': [1, 2, 4, 8],
    'model__criterion': ['gini', 'entropy'],
    'model__class_weight': ['balanced', {0: 1, 1: 2}, {0: 1, 1: 3}]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_dt = GridSearchCV(
    estimator=dt_pipeline,
    param_grid=param_grid_dt,
    scoring='f1',
    cv=cv,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_dt.fit(X_train, y_train)

best_dt = grid_dt.best_estimator_

print("\nBest Decision Tree hyperparameters:")
print(grid_dt.best_params_)
print(f"\nBest cross-validated F1 on training set: {grid_dt.best_score_:.4f}")

# Threshold tuning
val_probs_dt = best_dt.predict_proba(X_val)[:, 1]

thresholds_dt = np.arange(0.10, 0.91, 0.05)
threshold_rows_dt = []

for th in thresholds_dt:
    val_pred_dt = (val_probs_dt >= th).astype(int)
    threshold_rows_dt.append({
        'threshold': th,
        'precision': precision_score(y_val, val_pred_dt, zero_division=0),
        'recall': recall_score(y_val, val_pred_dt, zero_division=0),
        'f1': f1_score(y_val, val_pred_dt, zero_division=0)
    })

threshold_df_dt = pd.DataFrame(threshold_rows_dt).sort_values('f1', ascending=False)
best_threshold_dt = threshold_df_dt.iloc[0]['threshold']

print(f"\nSelected threshold based on validation F1: {best_threshold_dt:.2f}")
print(threshold_df_dt.head())

# Refit on train validation
best_dt.fit(X_trainval, y_trainval)



# Test evaluation
test_probs_dt = best_dt.predict_proba(X_test)[:, 1]
test_pred_dt = (test_probs_dt >= best_threshold_dt).astype(int)

test_accuracy_dt = accuracy_score(y_test, test_pred_dt)
test_precision_dt = precision_score(y_test, test_pred_dt, zero_division=0)
test_recall_dt = recall_score(y_test, test_pred_dt, zero_division=0)
test_f1_dt = f1_score(y_test, test_pred_dt, zero_division=0)
test_roc_auc_dt = roc_auc_score(y_test, test_probs_dt)
test_pr_auc_dt = average_precision_score(y_test, test_probs_dt)

print("\nDecision Tree Test Results")
print(f"Accuracy : {test_accuracy_dt:.4f}")
print(f"Precision: {test_precision_dt:.4f}")
print(f"Recall   : {test_recall_dt:.4f}")
print(f"F1-score : {test_f1_dt:.4f}")
print(f"ROC-AUC  : {test_roc_auc_dt:.4f}")
print(f"PR-AUC   : {test_pr_auc_dt:.4f}\n")

print("Decision Tree Classification report:")
print(classification_report(
    y_test,
    test_pred_dt,
    target_names=['Slight', 'Fatal/ Serious']
))

dt_results = {
    # 'Train_Share': X_train.shape[0] / len(X),
    # 'Validation_Share': X_val.shape[0] / len(X),
    # 'Test_Share': X_test.shape[0] / len(X),
    # 'Best_CV_F1': grid_dt.best_score_,
    # 'Best_Threshold': best_threshold_dt,
    'Test_Accuracy': test_accuracy_dt,
    'Test_Precision': test_precision_dt,
    'Test_Recall': test_recall_dt,
    'Test_F1': test_f1_dt,
    'Test_ROC_AUC': test_roc_auc_dt,
    'Test_PR_AUC': test_pr_auc_dt
}

print(dt_results)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
#
# Best Decision Tree hyperparameters:
# {'model__class_weight': {0: 1, 1: 3}, 'model__criterion': 'gini', 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}
#
# Best cross-validated F1 on training set: 0.4657
#
# Selected threshold based on validation F1: 0.45
#    threshold  precision    recall        f1
# 7       0.45   0.331699  0.849372  0.477086
# 6       0.40   0.331699  0.849372  0.477086
# 8       0.50   0.331699  0.849372  0.477086
# 9       0.55   0.433692  0.506276  0.467181
# 5       0.35   0.309524  0.924686  0.463799
#
# Decision Tree Test Results
# Accuracy : 0.4646
# Precision: 0.3116
# Recall   : 0.8201
# F1-score : 0.4516
# ROC-AUC  : 0.6355
# PR-AUC   : 0.3624
#
# Decision Tree Classification report:
#                 precision    recall  f1-score   support
#
#         Slight       0.83      0.33      0.48       650
# Fatal/ Serious       0.31      0.82      0.45       239
#
#       accuracy                           0.46       889
#      macro avg       0.57      0.58      0.46       889
#   weighted avg       0.69      0.46      0.47       889
#
# {'Test_Accuracy': 0.4645669291338583, 'Test_Precision': 0.31160572337042924, 'Test_Recall': 0.8200836820083682, 'Test_F1': 0.45161290322580644, 'Test_ROC_AUC': 0.6355069198583844, 'Test_PR_AUC': 0.3624086649558733}

# %% [markdown]
# ### 4.3. Random Forest

# %%
X = df_clean[numeric_features + categorical_features].copy()
y = df_clean['severity_levels'].copy()

# print("X shape:", X.shape)
# print("y distribution:")
# print(y.value_counts())
# print(y.value_counts(normalize=True).round(3))

# Train Test Split
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval,
    test_size=0.25,   # 25% of 80% = 20% of full data
    random_state=42,
    stratify=y_trainval
)

print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)

# Random forest pipline
rf_pipeline = Pipeline(steps=[
    ('transformed', transformed),
    ('model', RandomForestClassifier(
        random_state=42,
        n_jobs=-1
    ))
])


# Set prarms
param_grid_rf = {
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [5, 10, 15, None],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['sqrt', 'log2'],
    'model__class_weight': ['balanced', {0: 1, 1: 2}, {0: 1, 1: 3}]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_rf = GridSearchCV(
    estimator=rf_pipeline,
    param_grid=param_grid_rf,
    scoring='f1', # choose f1 cus data imbalance
    cv=cv,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)


grid_rf.fit(X_train, y_train)

best_rf = grid_rf.best_estimator_

print("\nBest hyperparameters:")
print(grid_rf.best_params_)

print(f"\nBest cross-validated F1 in training: {grid_rf.best_score_:.4f}")


# Threshold tuning
val_probs_rf = best_rf.predict_proba(X_val)[:, 1]

thresholds_rf = np.arange(0.10, 0.91, 0.05)
threshold_rows_rf = []

for th in thresholds_rf:
    val_pred_rf = (val_probs_rf >= th).astype(int)
    threshold_rows_rf.append({
        'threshold': th,
        'precision': precision_score(y_val, val_pred_rf, zero_division=0),
        'recall': recall_score(y_val, val_pred_rf, zero_division=0),
        'f1': f1_score(y_val, val_pred_rf, zero_division=0)
    })

threshold_df_rf = pd.DataFrame(threshold_rows_rf).sort_values('f1', ascending=False)

best_threshold_rf = threshold_df_rf.iloc[0]['threshold']

print(f"\Best threshold from F1 score: {best_threshold_rf:.2f}")

# Best 
best_rf.fit(X_trainval, y_trainval)

test_probs_rf = best_rf.predict_proba(X_test)[:, 1]
test_pred_rf = (test_probs_rf >= best_threshold_rf).astype(int)

test_accuracy_rf = accuracy_score(y_test, test_pred_rf)
test_precision_rf = precision_score(y_test, test_pred_rf, zero_division=0)
test_recall_rf = recall_score(y_test, test_pred_rf, zero_division=0)
test_f1_rf = f1_score(y_test, test_pred_rf, zero_division=0)
test_roc_auc_rf = roc_auc_score(y_test, test_probs_rf)
test_pr_auc_rf = average_precision_score(y_test, test_probs_rf)

print("\nRandom Forest Test Results")
print(f"Accuracy : {test_accuracy_rf:.4f}")
print(f"Precision: {test_precision_rf:.4f}")
print(f"Recall   : {test_recall_rf:.4f}")
print(f"F1-score : {test_f1_rf:.4f}")
print(f"ROC-AUC  : {test_roc_auc_rf:.4f}")
print(f"PR-AUC   : {test_pr_auc_rf:.4f}\n")

print("Reandom Forest Classification report:")
print(classification_report(
    y_test,
    test_pred_rf,
    target_names=['Slight', 'Fatal/ Serious']
))


# Save as a dictionary
rf_results = {
    # 'Train_Share': X_train.shape[0] / len(X),
    # 'Validation_Share': X_val.shape[0] / len(X),
    # 'Test_Share': X_test.shape[0] / len(X),
    # 'Best_CV_F1': grid_rf.best_score_,
    # 'Best_Threshold': best_threshold_rf,
    'Test_Accuracy': test_accuracy_rf,
    'Test_Precision': test_precision_rf,
    'Test_Recall': test_recall_rf,
    'Test_F1': test_f1_rf,
    'Test_ROC_AUC': test_roc_auc_rf,
    'Test_PR_AUC': test_pr_auc_rf
}
# Out:
# X shape: (4445, 33)
# y distribution:
# severity_levels
# 0    3249
# 1    1196
# Name: count, dtype: int64
# severity_levels
# 0    0.731
# 1    0.269
# Name: proportion, dtype: float64
# Train: (2667, 33) (2667,)
# Validation: (889, 33) (889,)
# Test: (889, 33) (889,)
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#
# Best hyperparameters:
# {'model__class_weight': {0: 1, 1: 3}, 'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__n_estimators': 200}
#
# Best cross-validated F1 in training: 0.4789
# \Best threshold from F1 score: 0.50
#
# Random Forest Test Results
# Accuracy : 0.5512
# Precision: 0.3496
# Recall   : 0.7782
# F1-score : 0.4825
# ROC-AUC  : 0.6876
# PR-AUC   : 0.4524
#
# Reandom Forest Classification report:
#                 precision    recall  f1-score   support
#
#         Slight       0.85      0.47      0.60       650
# Fatal/ Serious       0.35      0.78      0.48       239
#
#       accuracy                           0.55       889
#      macro avg       0.60      0.62      0.54       889
#   weighted avg       0.72      0.55      0.57       889

# %% [markdown]
# ### 4.4. Random Forest Without Greenspace

# %%
# Define feature set without greenspace
numeric_features_rf2 = [
    'age_of_casualty',
    'longitude',
    'latitude',
    'number_of_vehicles',
    'age_of_driver',
    'age_of_vehicle',
    'engine_capacity_cc',
    'hour'
]

categorical_features_rf2 = categorical_features.copy()

# Keep only columns that actually exist
numeric_features_rf2 = [col for col in numeric_features_rf2 if col in df_clean.columns]
categorical_features_rf2 = [col for col in categorical_features_rf2 if col in df_clean.columns]

# Build X and y
X_rf2 = df_clean[numeric_features_rf2 + categorical_features_rf2].copy()
y_rf2 = df_clean['severity_levels'].copy()

print("X_rf2 shape:", X_rf2.shape)
print("y_rf2 distribution:")
print(y_rf2.value_counts())
print(y_rf2.value_counts(normalize=True).round(3))

# Train / validation / test split
X_trainval_rf2, X_test_rf2, y_trainval_rf2, y_test_rf2 = train_test_split(
    X_rf2, y_rf2,
    test_size=0.20,
    random_state=42,
    stratify=y_rf2
)

X_train_rf2, X_val_rf2, y_train_rf2, y_val_rf2 = train_test_split(
    X_trainval_rf2, y_trainval_rf2,
    test_size=0.25,   # 25% of 80% = 20% of full data
    random_state=42,
    stratify=y_trainval_rf2
)

print("Train:", X_train_rf2.shape, y_train_rf2.shape)
print("Validation:", X_val_rf2.shape, y_val_rf2.shape)
print("Test:", X_test_rf2.shape, y_test_rf2.shape)

# Preprocessing pipeline for rf2
numeric_pipeline_rf2 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_pipeline_rf2 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

transformed_rf2 = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline_rf2, numeric_features_rf2),
        ('cat', categorical_pipeline_rf2, categorical_features_rf2)
    ]
)

# Random forest pipeline
rf2_pipeline = Pipeline(steps=[
    ('transformed', transformed_rf2),
    ('model', RandomForestClassifier(
        random_state=42,
        n_jobs=-1
    ))
])

# Same parameter grid as rf
param_grid_rf2 = {
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [5, 10, 15, None],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['sqrt', 'log2'],
    'model__class_weight': ['balanced', {0: 1, 1: 2}, {0: 1, 1: 3}]
}

cv_rf2 = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_rf2 = GridSearchCV(
    estimator=rf2_pipeline,
    param_grid=param_grid_rf2,
    scoring='f1',
    cv=cv_rf2,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

# Fit rf2
grid_rf2.fit(X_train_rf2, y_train_rf2)

best_rf2 = grid_rf2.best_estimator_

print("\nBest rf2 hyperparameters:")
print(grid_rf2.best_params_)

print(f"\nBest cross-validated F1 in training (rf2): {grid_rf2.best_score_:.4f}")

# Threshold tuning
val_probs_rf2 = best_rf2.predict_proba(X_val_rf2)[:, 1]

thresholds_rf2 = np.arange(0.10, 0.91, 0.05)
threshold_rows_rf2 = []

for th in thresholds_rf2:
    val_pred_rf2 = (val_probs_rf2 >= th).astype(int)
    threshold_rows_rf2.append({
        'threshold': th,
        'precision': precision_score(y_val_rf2, val_pred_rf2, zero_division=0),
        'recall': recall_score(y_val_rf2, val_pred_rf2, zero_division=0),
        'f1': f1_score(y_val_rf2, val_pred_rf2, zero_division=0)
    })

threshold_df_rf2 = pd.DataFrame(threshold_rows_rf2).sort_values('f1', ascending=False)

best_threshold_rf2 = threshold_df_rf2.iloc[0]['threshold']

print(f"\nBest threshold from F1 score (rf2): {best_threshold_rf2:.2f}")
print(threshold_df_rf2.head())

# Refit on full train+validation set
best_rf2.fit(X_trainval_rf2, y_trainval_rf2)

# Test evaluation
test_probs_rf2 = best_rf2.predict_proba(X_test_rf2)[:, 1]
test_pred_rf2 = (test_probs_rf2 >= best_threshold_rf2).astype(int)

test_accuracy_rf2 = accuracy_score(y_test_rf2, test_pred_rf2)
test_precision_rf2 = precision_score(y_test_rf2, test_pred_rf2, zero_division=0)
test_recall_rf2 = recall_score(y_test_rf2, test_pred_rf2, zero_division=0)
test_f1_rf2 = f1_score(y_test_rf2, test_pred_rf2, zero_division=0)
test_roc_auc_rf2 = roc_auc_score(y_test_rf2, test_probs_rf2)
test_pr_auc_rf2 = average_precision_score(y_test_rf2, test_probs_rf2)

print("\nRandom Forest without Greenspace Test Results")
print(f"Accuracy : {test_accuracy_rf2:.4f}")
print(f"Precision: {test_precision_rf2:.4f}")
print(f"Recall   : {test_recall_rf2:.4f}")
print(f"F1-score : {test_f1_rf2:.4f}")
print(f"ROC-AUC  : {test_roc_auc_rf2:.4f}")
print(f"PR-AUC   : {test_pr_auc_rf2:.4f}\n")

print("Random Forest without Greenspace Classification report:")
print(classification_report(
    y_test_rf2,
    test_pred_rf2,
    target_names=['Slight', 'Fatal/ Serious']
))

# Save rf2 results
rf2_results = {
    'Test_Accuracy': test_accuracy_rf2,
    'Test_Precision': test_precision_rf2,
    'Test_Recall': test_recall_rf2,
    'Test_F1': test_f1_rf2,
    'Test_ROC_AUC': test_roc_auc_rf2,
    'Test_PR_AUC': test_pr_auc_rf2
}

print("\nrf2_results:")
print(rf2_results)
# Out:
# X_rf2 shape: (4445, 32)
# y_rf2 distribution:
# severity_levels
# 0    3249
# 1    1196
# Name: count, dtype: int64
# severity_levels
# 0    0.731
# 1    0.269
# Name: proportion, dtype: float64
# Train: (2667, 32) (2667,)
# Validation: (889, 32) (889,)
# Test: (889, 32) (889,)
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#
# Best rf2 hyperparameters:
# {'model__class_weight': {0: 1, 1: 3}, 'model__max_depth': 5, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__n_estimators': 300}
#
# Best cross-validated F1 in training (rf2): 0.4726
#
# Best threshold from F1 score (rf2): 0.50
#    threshold  precision    recall        f1
# 8       0.50   0.342541  0.778243  0.475703
# 7       0.45   0.313433  0.878661  0.462046
# 9       0.55   0.423792  0.476987  0.448819
# 6       0.40   0.290837  0.916318  0.441532
# 5       0.35   0.279811  0.991632  0.436464
#
# Random Forest 2 (WITHOUT GREENSPACE) Test Results
# Accuracy : 0.5377
# Precision: 0.3413
# Recall   : 0.7741
# F1-score : 0.4738
# ROC-AUC  : 0.6873
# PR-AUC   : 0.4484
#
# Random Forest 2 Classification report:
#                 precision    recall  f1-score   support
#
#         Slight       0.84      0.45      0.59       650
# Fatal/ Serious       0.34      0.77      0.47       239
#
#       accuracy                           0.54       889
#      macro avg       0.59      0.61      0.53       889
#   weighted avg       0.71      0.54      0.56       889
#
#
# rf2_results:
# {'Test_Accuracy': 0.5376827896512936, 'Test_Precision': 0.3413284132841328, 'Test_Recall': 0.7740585774058577, 'Test_F1': 0.4737516005121639, 'Test_ROC_AUC': 0.6873060830383007, 'Test_PR_AUC': 0.4484453024381625}

# %% [markdown]
# ### 4.5. Model Comparison

# %%
import pandas as pd
results_df = pd.DataFrame({
  'Decision Tree': dt_results,
  'Random Forest': rf_results,
  'Random Forest without Greenspace Predictor': rf2_results
}).T
print(results_df.round(3))
# Out:
#                                             Test_Accuracy  Test_Precision  \
# Decision Tree                                       0.465           0.312
# Random Forest                                       0.551           0.350
# Random Forest without Greenspace Predictor          0.538           0.341
#
#                                             Test_Recall  Test_F1  \
# Decision Tree                                     0.820    0.452
# Random Forest                                     0.778    0.482
# Random Forest without Greenspace Predictor        0.774    0.474
#
#                                             Test_ROC_AUC  Test_PR_AUC
# Decision Tree                                      0.636        0.362
# Random Forest                                      0.688        0.452
# Random Forest without Greenspace Predictor         0.687        0.448

# %% [markdown]
# The Random Forest outperformed the Decision Tree across most evaluation metrics. Although the Decision Tree achieved slightly higher recall for fatal or serious pedestrian outcomes, the Random Forest produced better overall classification performance, with higher accuracy, precision, F1-score, ROC-AUC, and PR-AUC. This suggests that the Random Forest provided a better balance between identifying severe cases and reducing false positives, and was therefore selected as the preferred model for interpretation.
#
# Furthermore, adding distance to the nearest greenspace access point produced a small improvement in predictive performance across all evaluation metrics, but the improvement was marginal. This suggests that greenspace accessibility contributes only limited additional explanatory value beyond pedestrian, collision, road environment, vehicle, and driver characteristics.

# %% [markdown]
# ## 4.6. SHAP Model Interpretation

# %%
import shap
import numpy as np

# for faster plotting, sample test data
X_test_sample = X_test.sample(n=min(500, len(X_test)), random_state=42)

# use the fitted preprocessing step and fitted RF from your best pipeline
preprocessor = best_rf.named_steps['transformed']
rf_model = best_rf.named_steps['model']

# transform test data into the same format seen by the RF
X_test_sample_transformed = preprocessor.transform(X_test_sample)

# convert sparse matrix to dense if needed
if hasattr(X_test_sample_transformed, "toarray"):
    X_test_sample_transformed = X_test_sample_transformed.toarray()

# force numeric dtype
X_test_sample_transformed = np.asarray(X_test_sample_transformed, dtype=np.float64)

# get transformed feature names
feature_names = preprocessor.get_feature_names_out()
feature_names = [f.replace("num__", "").replace("cat__", "") for f in feature_names]

# SHAP explainer
explainer = shap.TreeExplainer(rf_model)
shap_values = explainer(X_test_sample_transformed)

print("SHAP values shape:", shap_values.values.shape)

# keep class 1 = fatal/serious
shap_values_class1 = shap.Explanation(
    values=shap_values.values[:, :, 1],
    base_values=shap_values.base_values[:, 1],
    data=shap_values.data,
    feature_names=feature_names
)

print("Class 1 SHAP shape:", shap_values_class1.values.shape)
# Out:
# SHAP values shape: (500, 174, 2)
# Class 1 SHAP shape: (500, 174)

# %%
# Beeswarm plot with dummy encoded features
shap.plots.beeswarm(shap_values_class1, max_display=20, show=False)
plt.title("SHAP Feature Importance of Encoded Features for Fatal / Serious", 
          fontsize=13, pad=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Greenspace accessibility contributed lightly on explanatory value for severe pedestrian injury when pedestrian, road, collision, vehicle, and driver variables were accounted for. SHAP analysis identified casualty age, junction-related variables, vehicle manoeuvre, driver characteristics, and road context as the primary predictors. Distance to the nearest greenspace access point was retained in the final random forest model but carried a low mean absolute SHAP value of 0.0031, indicating that it contributes relatively less in comparison to the characteristics of the collision environment and individuals involved.

# %%
# Group dummies into original variables for SHAP interpretation

# Define original variable 
all_original_features = numeric_features + categorical_features

# Get transformed feature names and SHAP values
feat_names = list(shap_values_class1.feature_names)  # 174 names
shap_vals  = shap_values_class1.values               # (500, 174)

# Group dummy columns to original variables
grouped_shap = np.zeros((shap_vals.shape[0], len(all_original_features)))
grouped_data = np.zeros((shap_vals.shape[0], len(all_original_features)))

for col_idx, orig in enumerate(all_original_features):
    if orig in numeric_features:
        if orig in feat_names:
            i = feat_names.index(orig)
            grouped_shap[:, col_idx] = shap_vals[:, i]
            grouped_data[:, col_idx] = shap_values_class1.data[:, i]
    else:
        indices = [i for i, name in enumerate(feat_names)
                   if name.startswith(orig + '_') or name == orig]
        if indices:
            grouped_shap[:, col_idx] = shap_vals[:, indices].sum(axis=1)
            grouped_data[:, col_idx] = np.abs(shap_vals[:, indices]).sum(axis=1)

# Rebuild grouped Explanation object
grouped_explanation = shap.Explanation(
    values        = grouped_shap,
    base_values   = shap_values_class1.base_values,
    data          = grouped_data,
    feature_names = all_original_features
)

# Plots summary stats
ranked  = pd.Series(
    np.abs(grouped_explanation.values).mean(axis=0),
    index=all_original_features
).sort_values(ascending=False)

gs_val  = ranked['dist_to_greenspace_m']
rank_gs = ranked.index.tolist().index('dist_to_greenspace_m') + 1

print("=" * 50)
print("Top 20 most important original features:")
print(ranked.head(20).round(5).to_string())
print("=" * 50)
print(f"Greenspace SHAP mean: {gs_val:.5f}")
print(f"Greenspace rank:{rank_gs} out of {len(ranked)}")
print("=" * 50)
# Out:
# ==================================================
# Top 20 most important original features:
# age_of_casualty         0.02690
# vehicle_manoeuvre       0.02646
# junction_location       0.02487
# sex_of_driver           0.02239
# latitude                0.00691
# light_conditions        0.00624
# driver_imd_decile       0.00598
# first_road_class        0.00512
# road_type               0.00511
# age_of_vehicle          0.00499
# junction_detail         0.00413
# engine_capacity_cc      0.00404
# age_of_driver           0.00384
# vehicle_type            0.00369
# junction_control        0.00314
# dist_to_greenspace_m    0.00310
# pedestrian_location     0.00206
# pedestrian_movement     0.00195
# pedestrian_crossing     0.00180
# longitude               0.00175
# ==================================================
# Greenspace mean |SHAP|: 0.00310
# Greenspace rank:        16 out of 33
# ==================================================

# %% [markdown]
# *[Note: a flow chart that describes the methodology is strongly encouraged - see the example below. This flow chart can be made using Microsoft powerpoint or visio or other software]*
#
# Source: see [link](https://linkinghub.elsevier.com/retrieve/pii/S2210670722004437).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Results and discussion
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# **Model Performance**
#
#
# **RQ1:** SHAP analysis from the weighted Random Forest identified the most featured importance predictors of pedestrian injury severity. Casualty age is found as the most influential variable, consistent with greater physiological vulnerability among older pedestrians, who are substantially more likely to acquire fatal or serious outcomes. Junction related variables of junction_detail and junction_location also ranked highly, reflecting that the presence of concentration of severe collisions at complex navigation points where vehicle movements may collide with pedestrian usages. Vehicle manoeuvre and vehicle type also carried meaningful explanatory weight, positioning the importance of collision physics in determining severity outcome. Driver-level demographic variables, including age_of_driver and sex_of_driver contributed additional explanatory value, suggesting that driver behaviour and reaction capacity are also relevant factors. Road environment variables, such as speed limit and pedestrian crossing type are featured in the at lower parts of the SHAP rankings, indicating a secondary but a substaintial structural influence on severity.
#
# **RQ2:** Distance to the nearest greenspace access point was preserved in the main Random Forest model as a spatial contextual variable. Its mean absolute SHAP value was found as 0.0031, placing it at a lower position as a predictor in the model. Once pedestrian, junction, vehicle, and driver characteristics were accounted for, greenspace proximity contributed negligible additional explanatory value. This suggests that, within the analytical framework applied here, the immediate physical and human characteristics of the collision environment are far stronger determinants of injury severity than the surrounding spatial context.
#
# It is also important to recognise that several predictor variables, such as road class, speed limit, and junction-related features, are likely to exhibit multicollinearity. This may lead to SHAP interpretation to skew feature importance rankings by splitting attribution across correlated variables. However, this does not undermine the Random Forest model itself, as it makes decisions through splitting nodes which reduces the impact of multicollinearity on predictive performance. While the model remains robust in predictions, it is also important to note that there may still be a possibility that the individual contribution of certain road environment features may be slightly underestimated with SHAP.

# %% [markdown]
# ## 6. Conclusion
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# Pedestrian age and junction complexity were the most important predictors of severity levels, reflecting both biological vulnerability and structural risk of road users. The model achieved a recall of 78%, making it a viable screening tool for transport planners seeking to identify potentially lethal road configurations, accepting lower precision in exchange for greater sensitivity. Despite greenspace accessibility to be relevant to wider urban health outcomes, yet it did not emerge as a primary driver of injury severity when modelled against conventional traffic engineering factors.
#
# These findings also has direct policy relevance, supporting the "Vision Zero" strategy in London's transport system, particularly speed reduction and improved junction visibility, especially in areas with higher concentrations of higher aged pedestrian road users, where such measures carry greater weight than wider environmental features in determining collision outcomes.

# %% [markdown]
# ## 7. References
#
# [[ go back to the top ]](#Table-of-contents)
