# %% [markdown]
# # Pedestrian Collision Severity in London: Does Greenspace Accessibility Matter Beyond Collision and Casualty Factors?

# %% [markdown]
# ## Preface
#
# - GitHub Repository: [View link](https://github.com/christychoicc/DSSS_Coursework)
#
# - Number of words: ***
#
# - Runtime: 651 seconds
#
# - Coding environment: SDS Docker (or anything else)
#
# - License: this notebook is made available under the [Creative Commons Attribution license](https://creativecommons.org/licenses/by/4.0/) (or other license that you like).
#
# - Additional library *[libraries not included in SDS Docker or not used in this module]*:
#     - **watermark**: A Jupyter Notebook extension for printing timestamps, version numbers, and hardware information.
#     - ......
#
# - Declaration: LLM is used for fixing coding and grammar mistakes.

# %% [markdown]
# ## Table of contents
#
# 1. [Introduction](#Introduction)
#
# 1. [Research questions](#Research-questions)
#
# 1. [Data](#Data)
#
# 1. [Methodology](#Methodology)
#
# 1. [Results and discussion](#Results-and-discussion)
#
# 1. [Conclusion](#Conclusion)
#
# 1. [References](#References)

# %% [markdown]
# ## 1. Introduction
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# Pedestrian road safety is a urban policy and health challenge. Road collision events are found to be an interplay between human behaviour, vehicle characteristics, environmental conditions and the characteristics of the infrastructure (Hossain et al., 2026). Under complex urban contexts like London, pedestrians are the most vulnerable, facing disproportionately more severe injury outcomes in comparison to other road users (Pour-Rouholamin and Zhou, 2016).  The World Health Organization (2023) reported that more than half of global road traffic fatalities involve vulnerable road users, highlighting the urge of understanding and addressing the challenge. Walking is also a fundamental mode of transport within the built environment, delivering benefits for urban health, community, and environmental sustainability (Mayor of London and Transport for London, n.d.). Pedestrian collisions, as a leading cause of deaths and serious injuries, therefore, make the factors shaping pedestrian injury severity an important policy concern.
#
# In London, pedestrian road measures and urban greening strategies both intersects on policy priorities. The Mayor of London aims for promoting "Green Transport" and a "Vision Zero" in eliminating all deaths and serious injuries from road collisions by 2041, targeting safer streets, safer speeds and the transformation of dangerous junctions (Mayor of London and Transport for London, n.d.; Transport for London, n.d.). On the other hand, the London Plan 2021 policies G1, G3 and G4 recognised green infrastructure as a facilitator for walking opportunities and urban health, while the Green Transport strategy further positions urban greening as an incentive to making walking more attractive (Mayor of London, 2021). Despite strong policy commitments links, whether proximity to greenspace shapes pedestrian collision outcomes beyond widely recognised traffic and casualty factors remains underexplored.
#
# Existing literature identifies pedestrian demographics, vehicle type and manoeuvre, road conditions, environmental aspects, and junction characteristics as the primary determinants of collision severity (Elalouf, Birfir and Rosenbloom, 2023). Both personal and built environment characteristics explain injury severity, alongside driver and road factors (Clifton, Burnier and Akar, 2009). As policies intersects, whether greenspace indirectly shape collision risk by attracting pedestrian foot traffic and altering route exposure characteristics remains absent from current studies.
# Therefore, this analysis aims to address the gap by examining London pedestrian road safety data for 2024, testing whether proximity to urban greenspace contributes to fatal or serious injury outcomes after accounting for casualty, collision and vehicle factors. A better understanding of factors is fundamental to implement appropriate policy strategies toward a safer and greener London (Pour-Rouholamin and Zhou, 2016).

# %% [markdown]
# ## 2. Research Question
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# Pedestrian safety is a major urban policy and public health concern because severe pedestrian injuries reflect not only traffic conditions, but also the interaction between urban design, pedestrian behaviour, environmental context, and neighbourhood characteristics. This study will focus on pedestrian collisions in London and examine whether urban greenspace accessibility contributes meaningful explanatory value beyond collision and casualty factors. Therefore, the analysis aims to answer the following research questions:
#
# **RQ1** - Which factors most influences most in the prediction of fatal or serious pedestrian injuries in London in 2024?
#
# **RQ2** - Does proximity to urban greenspace access points add meaningful explanatory power for predicting pedestrian injury severity, after accounting for casualty, collision, and road environment characteristics?

# %% [markdown]
# ## 3. Data
#
# [[ go back to the top ]](#Table-of-contents)
#
# **Section Overview**
#
# In this section, relevant datasets are pre-processed, cleaned and wrangled in preparation for......
# - 3.1. Data Evaluation
# - 3.2. Load Packages
# - 3.3. Data Loading
# - 3.4. Data Pre-processing
#   - 3.4.1. Data Cleaning
#   - 3.4.2. Data Merge/ Join
# - 3.5. Data Wrangling
#   - 3.5.1. Data Ambiguity
#   - 3.5.2. Variable Confounding Relationship Check
#   - 3.5.3. Modelling Variables Preparation
# - 3.6. Metadata (Model Variables)

# %% [markdown]
# ### 3.1. Data Evaluation
#
# #### 3.1.1. Data Sources:
# This analysis uses the following datasets:
#
# 1. **[Road Safety Collision data (2024)](https://www.gov.uk/government/statistical-data-sets/road-safety-open-data)**: This dataset contains collision-level information including location, road characteristics, environmental conditions, and counts of vehicles and casualties.
#
# 2. **[Road Safety Casualty data (2024)](https://www.gov.uk/government/statistical-data-sets/road-safety-open-data)**: This dataset contains casualty-level information including casualty severity, pedestrian movement, pedestrian location, age, sex, and area-level deprivation indicators.
#
# 3. **[Road Safety Vehicle data (2024)](https://www.gov.uk/government/statistical-data-sets/road-safety-open-data)**
#
# 4. **[OS Open Greenspace Access Point data](https://osdatahub.os.uk/data/downloads/open/OpenGreenspace?_gl=1*lcmfh4*_ga*ODk4MTE3Nzk4LjE3NzU1ODM0ODg.*_ga_59ZBN7DVBG*czE3NzU1ODM0ODckbzEkZzAkdDE3NzU1ODM2NDgkajYwJGwwJGgw)**
#
# 5. **[London LSOA boundary data](https://data.london.gov.uk/dataset/statistical-gis-boundary-files-for-london-20od9/)**: This dataset is used for spatial filtering to study area, mapping purposes.
#
# 6. **[London LSOA Population Data](https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/populationestimates/datasets/lowersuperoutputareamidyearpopulationestimates)**: This dataset is pre-loaded and pre-filtered to London and 2024 data only, for mapping purposes
#
# #### 3.1.2. Data Limitations
# There are two main data limitations in the road safety datasets that may impact the analytical scope of this study. The open release excludes the contributory factors table, which captures officer-recorded behavioural causes of collisions such as driver inattention, failure to observe, or excessive speed. Research has demonstrated that incorporating these variables substantially improves the predictive performance of injury severity models, and their absence from the open release on privacy grounds places a ceiling on what can reasonably be achieved from open data alone. Additionally, UK police forces began transitioning from officer-assessed to injury-based severity recording from 2016 onwards. Although this study is restricted to London collisions in 2024, the possibility that residual inconsistency in severity classification introduces noise into the target variable cannot be fully discounted and is acknowledged as a limitation of the underlying data.

# %% [markdown]
# ### 3.2. Load Packages

# %%
# Packages to install first prior to importing
# %pip install shap

# %%
# Packages for data processing and analysis

# --------------------------------- Data Wrangling and EDA -----------------------------------
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

import warnings
warnings.filterwarnings('ignore')

# ------------------------------------ Preprocessing --------------------------------------
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# ------------------------------------ Model Selection --------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# ------------------------------------ Machine Learning --------------------------------------
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import SelectFromModel

# ----------------------------------- Accuracy Assessment -------------------------------------
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report,
    roc_auc_score, average_precision_score,
    ConfusionMatrixDisplay, PrecisionRecallDisplay, RocCurveDisplay
)

# ----------------------------------- Model Interpretation -------------------------------------
import shap

# %% [markdown]
# ### 3.3. Data Loading

# %%
# Load Collision 2024
collision = pd.read_csv("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/dft-road-casualty-statistics-collision-2024.csv", low_memory=False)

# Load Casualty 2024 
casualty = pd.read_csv("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/dft-road-casualty-statistics-casualty-2024.csv", low_memory=False)

# Load Vehicle 2024 
vehicle = pd.read_csv("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/dft-road-casualty-statistics-vehicle-2024.csv", low_memory=False)

# Load Green Space data
greenspace = gpd.read_file("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/OS-Open-Greenspace-GB/GB_AccessPoint.shp")

# Load London LOSA boundary data
london_lsoa = gpd.read_file("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/london_LSOA_boundary/LSOA_2011_London_gen_MHW.shp")

# Load Lower layer Super Output Area population estimates data
london_lsoa_pop = pd.read_csv("https://raw.githubusercontent.com/christychoicc/DSSS_Coursework/main/lsoa_pop_london_2024.csv", low_memory=False)
# The above file was pre-loaded and pre-filtered for analysis needs as original file size exceed github 50MB limits 
# Pre-loaded and pre-filtered code:
# lsoa_pop = pd.read_excel(
#     'sapelsoasyoa20222024.xlsx',
#     sheet_name='Mid-2024 LSOA 2021',
#     skiprows=4
# )
# # Extract needed data and saved as CSV
# pop = lsoa_pop.iloc[:, [2, 4]].copy()
# pop.columns = ['LSOA11CD', 'population']
# pop_london = pop[pop['LSOA11CD'].str.startswith('E01')].copy()
# pop_london.to_csv('lsoa_pop_london_2024.csv', index=False)

# Standardise column names
collision.columns = collision.columns.str.strip().str.lower()
casualty.columns = casualty.columns.str.strip().str.lower()
vehicle.columns = vehicle.columns.str.strip().str.lower()
greenspace.columns = greenspace.columns.str.strip().str.lower()

# %%
# # Data Inspection

# # Inspect number of rows and columns for all dataset
# print("Collision data shape:", collision.shape)
# print("Casualty data shape:", casualty.shape)
# print("Vehicle data shape:", vehicle.shape)
# print("Greenspace data shape:", greenspace.shape)
# print("London LSOA shape:", london_lsoa.shape)

# # Inspect CRS for greenspace and London boundary data
# print("\nGreenspace CRS:", greenspace.crs)
# print("London LSOA CRS:", london_lsoa.crs)

# # Inspect column names for all dataset
# print("\nCollision Column names:")
# print(collision.columns.tolist())
# print("\nCasualty Column names:")
# print(casualty.columns.tolist())
# print("\nVehicle Column names:")
# print(vehicle.columns.tolist())
# print("\nGreenspace Column names:")
# print(greenspace.columns.tolist())

# %% [markdown]
# ### 3.4. Data Pre-processing

# %% [markdown]
# #### 3.4.1. Data Cleaning

# %%
# Filter to London collisions only
collision_london = collision[
    collision['local_authority_ons_district'].astype(str).str.startswith('E09')
].copy()

# print("London collisions shape:", collision_london.shape)
# print(collision_london['local_authority_ons_district'].nunique())

# %%
# Filter Greenspace data to London only
london_boundary = london_lsoa.dissolve()
# Ensure consistent CRS
greenspace = greenspace.to_crs(london_boundary.crs)
# Clip greenspace to the exact London boundary
greenspace_london = gpd.clip(greenspace, london_boundary)


# Transform geometry column's point(x y z) into normal point(x y) only
# Code provided from LLM (Claude AI)
greenspace_london['geometry'] = greenspace_london['geometry'].apply(
    lambda g: Point(g.x, g.y)  # drops Z, keeps X and Y only
)

# Create collision points for nearest greenspace distance
collision_points = gpd.GeoDataFrame(
    # remove duplicated collision_index
    collision_london[['collision_index', 'longitude', 'latitude']].dropna().drop_duplicates('collision_index'),
    # convert lat and long to geometry
    geometry=gpd.points_from_xy(
        collision_london[['collision_index', 'longitude', 'latitude']].dropna().drop_duplicates('collision_index')['longitude'],
        collision_london[['collision_index', 'longitude', 'latitude']].dropna().drop_duplicates('collision_index')['latitude']
    ),
    crs='EPSG:4326'
).to_crs('EPSG:27700')

# Nearest greenspace access p
collision_green_nearest = gpd.sjoin_nearest(
    collision_points,
    greenspace_london[['geometry']],
    how='left',
    distance_col='dist_to_greenspace_m'
)[['collision_index', 'dist_to_greenspace_m']].drop_duplicates('collision_index')

# Merge newly computed collisioin to nearest greenspace a.p. with london collision
collision_london = collision_london.merge(
    collision_green_nearest,
    on='collision_index',
    how='left'
)

# %%
# # Check new column data
# print(collision_london[['dist_to_greenspace_m']].describe())

# %%
# Filter to Pedestrian casualties only
# 3 = Pedestrians
casualty_ped = casualty[casualty['casualty_class'] == 3].copy()
# print(casualty_ped['casualty_class'].value_counts(dropna=False))

# %%
# Filter for London Pedestrian casualties only
casualty_ped_london = casualty_ped[
    casualty_ped['collision_index'].isin(collision_london['collision_index'])
].copy()

# print("London pedestrian casualties shape:", casualty_ped_london.shape)

# %%
# Check how many collision have more than one pedestrian casualty
peds_per_collision = casualty_ped_london.groupby('collision_index').size()

print("Number of pedestrian-collision rows:", len(casualty_ped_london))
print("Number of unique collisions involving pedestrians:", casualty_ped_london['collision_index'].nunique())
print("Number of collisions with >1 pedestrian casualty:", (peds_per_collision > 1).sum())
print("Maximum pedestrians in a single collision:", peds_per_collision.max())
# Out:
# Number of pedestrian-collision rows: 4445
# Number of unique collisions involving pedestrians: 4299
# Number of collisions with >1 pedestrian casualty: 127
# Maximum pedestrians in a single collision: 4

# %% [markdown]
# The analysis is conducted at the pedestrian casualty level, so each row represents one pedestrian casualty rather than one collision. In a small number of cases, a single collision involved more than one pedestrian casualty (127 collisions out of 4,299 pedestrian-involved collisions). This means observations are not fully independent in all cases, although the issue is limited in scale.

# %% [markdown]
# #### 3.4.2. Data Joins/ Merge

# %%
# Merge collision and casualty data on collision_index
merge = casualty_ped_london.merge(
    # drop duplicate columns for merge
    collision_london.drop(columns=['collision_year', 'collision_ref_no'], errors='ignore'),
    on='collision_index',
    how='left'
)

# print("After collision casualty merge:", merge.shape)

# %%
# Merge collision and casualty data with vehicle data
vehicle_merge = vehicle.drop(
    # drop duplicate columns for merge
    columns=['collision_year', 'collision_ref_no'],
    errors='ignore'
)

# Merge
merge2 = merge.merge(
    vehicle_merge,
    on=['collision_index', 'vehicle_reference'],
    how='left'
)

# # Check merged data shape
# print("After vehicle merge:", merge2.shape)

# %%
# # Check merge2 variables
# print(merge2.columns.tolist())

# %% [markdown]
# ### 3.5. Data Wrangling
# #### 3.5.1. Data Ambiguity (Missing, Unknown, Undefined, Others)

# %%
# Check ambiguity of potentially needed variables
ambiguous_codes = {
    # casualty (pedestrian data)
    'sex_of_casualty':          [-1, 9],
    'age_of_casualty':          [-1],
    'pedestrian_location':      [-1, 10],
    'pedestrian_movement':      [-1, 9],
    'pedestrian_road_maintenance_worker': [-1, 2], # also a type of pedestrian so include it
    'casualty_imd_decile':      [-1],

    # collision / road environment
    'speed_limit':              [-1, 99],
    'first_road_class':         [-1],
    'road_type':                [-1, 9],
    'junction_detail':          [-1, 99],
    'junction_control':         [-1, 9],
    'pedestrian_crossing':      [-1, 99],
    'light_conditions':         [-1],
    'weather_conditions':       [-1, 9],
    'road_surface_conditions':  [-1, 9],
    'urban_or_rural_area':      [-1],
    'trunk_road_flag':          [-1],

    # vehicle / driver
    'vehicle_type':             [-1, 99],
    'vehicle_manoeuvre':        [-1, 99],
    'junction_location':        [-1, 9],
    'sex_of_driver':            [-1, 3],
    'age_of_driver':            [-1],
    'driver_imd_decile':        [-1],
    'engine_capacity_cc':       [-1],
    'age_of_vehicle':           [-1]
}

# Print a summary table of unknown missing values
inspection_rows = []
for col, codes in ambiguous_codes.items():
    if col not in merge2.columns:
        continue
    
    total= len(merge2)
    actual_nan= merge2[col].isnull().sum()
    ambig_count= merge2[col].isin(codes).sum()
    total_missing= actual_nan + ambig_count
    pct= total_missing / total * 100
    inspection_rows.append({
        'variable': col,
        'total_rows': total,
        'actual_NaN': actual_nan,
        'ambiguous_codes': str(codes),
        'ambiguous_count': ambig_count,
        'total_missing': total_missing,
        'pct_missing': round(pct, 1)
    })

inspection_df = pd.DataFrame(inspection_rows).sort_values('pct_missing', ascending=False)
print("Missing / Unknown Data Inspection:")
print(inspection_df.to_string(index=False))
# Out:
# Missing / Unknown Data Inspection:
#                           variable  total_rows  actual_NaN ambiguous_codes  ambiguous_count  total_missing  pct_missing
#                 engine_capacity_cc        4445           0            [-1]             2134           2134         48.0
#                     age_of_vehicle        4445           0            [-1]             1904           1904         42.8
#                  driver_imd_decile        4445           0            [-1]             1811           1811         40.7
#                      sex_of_driver        4445           0         [-1, 3]             1539           1539         34.6
#                      age_of_driver        4445           0            [-1]             1525           1525         34.3
#                pedestrian_movement        4445           0         [-1, 9]             1523           1523         34.3
# ...

# %% [markdown]
# Variables coded for missing, unknown or other values were found present within the dataset. To solve the data ambiguity, these values were recoded to `NaN` so that they will be treated as missing data instead of real values. Missing numeric values will be imputed with a median value, and missing categorical values will be replaced with a "Missing" category.
#
# |Variable|Code|Code Interpretation|Action|
# |---|---|---|---|
# |pedestrian_movement|-1, 9|Missing / unknown or other|Recode to `NaN`, impute with categorical `Missing`|
# |junction_control|-1, 9|Missing / unknown|Recode to `NaN`, impute with categorical `Missing`|
# |vehicle_manoeuvre|-1, 99|Missing / unknown |Recode to `NaN`, impute with categorical `Missing`|
# |junction_location|-1, 9|Missing / unknown|Recode to `NaN`, impute with categorical `Missing`|
# |casualty_imd_decile|-1|Missing|Recode to `NaN`, impute with categorical `Missing`|
# |pedestrian_location|-1, 10|Missing / unknown or other|Recode to `NaN`, impute with categorical `Missing`|
# |junction_detail|-1, 99|Missing / unknown |Recode to `NaN`, impute with categorical `Missing`|
# |road_type|-1, 9|Missing / unknown|Recode to `NaN`, impute with categorical `Missing`|
# |pedestrian_crossing|-1, 99|Missing / unknown |Recode to `NaN`, impute with categorical `Missing`|
# |weather_conditions|-1, 9|Missing / unknown|Recode to `NaN`, impute with categorical `Missing`, keep `8 = Other`|
# |road_surface_conditions|-1, 9|Missing / unknown |Recode to `NaN`, impute with categorical `Missing`|
# |age_of_casualty|-1|Missing|Recode to `NaN`, impute with median|
# |vehicle_type|-1, 99|Missing / unknown vehicle type|Recode to `NaN`, impute with categorical `Missing`, keep `90 = Other vehicle`|
# |pedestrian_road_maintenance_worker|-1, 2|Missing / not known|Recode to `NaN`, impute with categorical `Missing`|
# |sex_of_casualty|-1, 9|Missing / unknown|Recode to `NaN`, impute with categorical `Missing`|
# |speed_limit|-1, 99|Missing / unknown|No action needed |
# |first_road_class|-1, 9|Missing / unknown|No action needed|
# |light_conditions|-1|Missing|No action needed |
# |urban_or_rural_area|-1|Missing|No action needed |
# |trunk_road_flag|-1|Missing|No action needed |
# |driver_imd_decile|-1|Missing|Exclude from modelling due to high levels of missing data|
# |sex_of_driver|-1, 3|Missing / not known|Exclude from modelling due to high levels of missing data|
# |age_of_driver|-1|Missing|Exclude from modelling due to high levels of missing data|
# |engine_capacity_cc|-1|Missing|Exclude from modelling due to high levels of missing data|
# |age_of_vehicle|-1|Missing|Exclude from modelling due to high levels of missing data|

# %%
# Variable that needs recoding
recode_nan = {
    # collision
    'junction_control': [-1, 9],
    'junction_detail': [-1, 99],
    'road_type': [-1, 9],
    'pedestrian_crossing': [-1, 99],
    'weather_conditions': [-1, 9],
    'road_surface_conditions': [-1, 9],

    # casualty
    'pedestrian_movement': [-1, 9],
    'casualty_imd_decile': [-1],
    'pedestrian_location': [-1, 10],
    'age_of_casualty': [-1],
    'pedestrian_road_maintenance_worker': [-1, 2], 
    'sex_of_casualty': [-1, 9],

    # vehicle
    'vehicle_manoeuvre': [-1, 99],
    'junction_location': [-1, 9],
    'vehicle_type': [-1, 99] # keep 90 = Others
}

# %%
# Set recode function
def apply_recode(df, recode_dict):
    df = df.copy()
    for col, bad_codes in recode_dict.items():
        if col in df.columns:
            df[col] = df[col].replace(bad_codes, np.nan)
    return df

# %%
# Apply recode functions to the merged dataset
merged = apply_recode(merge2, recode_nan)
# print("Merged and recoded clean study dataset shape:", merged.shape)

# %%
# # Check merged columns 
# print("\n Merged Dataframe Columns:")
# print(merged.columns.tolist())

# %% [markdown]
# #### 3.5.2. Variables Confounding Relationship Inspection

# %%
from scipy.stats import spearmanr

# Check correlation between greenspace distance and speed limit
greenspace_speedl_check = merged[['dist_to_greenspace_m', 'speed_limit']].copy()
greenspace_speedl_check['speed_limit'] = pd.to_numeric(greenspace_speedl_check['speed_limit'], errors='coerce')
greenspace_speedl_check = greenspace_speedl_check.dropna()

rho, pval = spearmanr(greenspace_speedl_check['dist_to_greenspace_m'], greenspace_speedl_check['speed_limit'])
print(f"Spearman correlation between greenspace distance and speed limit:")
print(f"ρ = {rho:.4f}, p = {pval:.4f}")

# Also show mean greenspace distance by speed limit
mean_gs = (
    merged.groupby('speed_limit')['dist_to_greenspace_m']
    .mean()
    .reset_index()
    .sort_values('speed_limit')
)
mean_gs['speed_limit'] = pd.to_numeric(mean_gs['speed_limit'], errors='coerce')
mean_gs = mean_gs.dropna().sort_values('speed_limit')
print("\nMean greenspace distance by speed limit:")
print(mean_gs.to_string(index=False))
# Out:
# Spearman correlation between greenspace distance and speed limit:
# ρ = 0.1235, p = 0.0000
#
# Mean greenspace distance by speed limit:
#  speed_limit  dist_to_greenspace_m
#           20            150.938074
#           30            180.468014
#           40            194.532716
#           50            199.818479
#           60            333.308242
#           70            643.755792

# %% [markdown]
# Prior to modelling, a potential confounding relationship between distance to the nearest greenspace access point and road speed limit was examined. Greenspace access points in London are mostly located within residential neighbourhoods with lower speed limits, while higher speed roads tend to pass through corridors with fewer greenspace access points. This urban pattern suggests that any observed association between greenspace proximity and pedestrian injury severity may be partially attributable to the correlated road speed environment rather than greenspace accessibility itself. The Spearman correlation showed a statistically significant relationship between the two variables with ρ = 0.124 and p < 0.001, indicating that collisions occurring closer to greenspace tend to have lower speed limits. Therefore, both variables will be included as predictors for tree-based modelling approaches, allowing greenspace accessibility to be modelled after accounting for road speed context.

# %% [markdown]
# #### 3.5.3. Modelling Variables Preparation

# %%
# Select needed columns
selected_columns = [
    # to create our target binary variable
    'casualty_severity',

    # casualty, pedestrian variables
    'sex_of_casualty',
    'age_of_casualty',
    'pedestrian_location',
    'pedestrian_movement',
    'pedestrian_road_maintenance_worker',
    'casualty_imd_decile',
    'lsoa_of_accident_location', # for mapping purposes

    # collision, road and environment variables
    'speed_limit',
    'first_road_class',
    'road_type',
    'junction_detail',
    'junction_control',
    'pedestrian_crossing',
    'light_conditions',
    'weather_conditions',
    'road_surface_conditions',
    'urban_or_rural_area',
    'trunk_road_flag',

    # vehicle, driver variables
    'vehicle_type',
    'vehicle_manoeuvre',
    'junction_location',
    # 'sex_of_driver', # Excluded for high levels missing data
    # 'age_of_driver', # Excluded for high levels missing data
    # 'age_of_vehicle', # Excluded for high levels missing data
    # 'driver_imd_decile', # Excluded for high levels missing data

     # spatial contextual variable
    'dist_to_greenspace_m'
]

selected_columns = [c for c in selected_columns if c in merged.columns]

df_clean = merged[selected_columns].copy()

# %% [markdown]
# ##### Recompute Severity Levels for Modelling

# %% [markdown]
# The severity levels variable is defined as:
#
# - **1 = fatal or serious pedestrian injury outcome**
# - **0 = slight pedestrian injury outcome**
#
# The analysis is conducted at the pedestrian casualty level, meaning that each row in the analytical dataset represents one pedestrian casualty involved in a road collision in London in 2024. A pedestrian casualty is encoded as 1 if their recorded injury severity is fatal or serious, and as 0 if it is slight. As the analysis is conducted at the pedestrian casualty level, some collisions may contribute more than one pedestrian collision event where multiple pedestrians injuries were involved. This is acknowledged as a limitation, as observations from the same collision event may not be entirely independent.
#
# Another reason to group severity levels into binary is to solve class imbalance issues as fatal cases are very little

# %%
# Check initial distribution of casualty severity categories
print("Casualty severity data distribution:")
print(df_clean['casualty_severity'].value_counts())

# Create a binary for our target (severity levels)
df_clean['severity_levels'] = np.where(df_clean['casualty_severity'].isin([1, 2]), 1, 0)
print("\nCasualty severity groupped binary:")
print(df_clean['severity_levels'].value_counts())
# Out:
# Casualty severity data distribution:
# casualty_severity
# 3    3249
# 2    1135
# 1      61
# Name: count, dtype: int64
#
# Casualty severity groupped binary:
# severity_levels
# 0    3249
# 1    1196
# Name: count, dtype: int64

# %%
# # Check data types in df_clean
# print("\n df_clean data types:")
# print(df_clean.dtypes)

# %% [markdown]
# ##### Data Type

# %%
# Define features by data type

# Numeric
numeric_features = [
    'age_of_casualty',
    'dist_to_greenspace_m'
]

# Categorical
categorical_features = [
    'sex_of_casualty',
    'pedestrian_location',
    'pedestrian_movement',
    'pedestrian_road_maintenance_worker',
    'casualty_imd_decile',
    'speed_limit',
    'first_road_class',
    'road_type',
    'junction_detail',
    'junction_control',
    'pedestrian_crossing',
    'light_conditions',
    'weather_conditions',
    'road_surface_conditions',
    'urban_or_rural_area',
    'trunk_road_flag',
    'vehicle_type',
    'vehicle_manoeuvre',
    'junction_location'
]

# Note* 
# severity_levels are targets so not included here
# casualty_severity used to create severity levels so not included here
# longitude and latitude not included here
# lsoa_of_accident_location not included here

# %%
# Assign categroical features as objects (aka categories make them not comparable numbers)

# Numeric columns
# Keep values as numeric
for col in numeric_features:
    if col in df_clean.columns:
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')

# Categorical columns
# Convert all non-missing values to strings --> keep missing as NaN
for col in categorical_features:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].apply(lambda x: np.nan if pd.isna(x) else str(x))

# %%
# Check numeric features are numeric
print("\nNumeric Features:")
print(df_clean[numeric_features].dtypes)

# Check categorical features are strings
print("\nCategorical Features:")
print(df_clean[categorical_features].dtypes)

# Check NaN is preserved correctly (not converted to string "nan")
print("\nNaNs:")
print(df_clean[categorical_features].isnull().sum()[df_clean[categorical_features].isnull().sum() > 0])
# Out:
# Numeric Features:
# age_of_casualty         float64
# dist_to_greenspace_m    float64
# dtype: object
#
# Categorical Features:
# sex_of_casualty                       object
# pedestrian_location                   object
# pedestrian_movement                   object
# pedestrian_road_maintenance_worker    object
# casualty_imd_decile                   object
# speed_limit                           object
# first_road_class                      object
# road_type                             object
# junction_detail                       object
# junction_control                      object
# pedestrian_crossing                   object
# light_conditions                      object
# weather_conditions                    object
# road_surface_conditions               object
# urban_or_rural_area                   object
# trunk_road_flag                       object
# vehicle_type                          object
# vehicle_manoeuvre                     object
# ...

# %% [markdown]
# ##### Impute Missing Values Before Modelling
# A pre-processing pipeline is used to prepare predictors for modelling. Numeric variables were imputed using the median and standardised, while categorical variables were imputed with a "Missing" category and one-hot encoded. A ColumnTransformer was used to allow application of different pre-processing workflow to different columns within the machine learning pipeline.

# %%
# Impute as Tree based methods cannot deal with NaNs

# Impute NaN with median
numeric_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Impute NaN with 'Missing'
categorical_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
    # onehot encode for dummy 
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Define column transformer --> to use in methodology later for trees
transformed = ColumnTransformer(
    transformers=[
        # numeric
        ('num', numeric_pipeline, numeric_features),
        # categorical
        ('cat', categorical_pipeline, categorical_features)
    ]
)

# %% [markdown]
# ### 3.6. Metadata (Model Variables)

# %% [markdown]
# The variables information below shows the cleaned dataframe prior to modelling. Additional preprocessing for tree-based methods analysis, including imputation, scaling, and one-hot encoding, were applied within the modelling pipeline and will not alter the cleaned dataframe structure.
#
# | Variable | Type | Description | Notes |
# |---|---|---|---|
# | severity_levels | Binary | Determine pedestrian injury severity levels: 1 = fatal or serious injury, 0 = slight injury | Target variable |
# | casualty_severity | Categorical | Recorded casualty severity levels: 1 = fatal, 2 = serious, 3 = slight | Used to create `severity_levels`variable, will be excluded from modelling |
# | sex_of_casualty | Categorical | Sex of the pedestrian casualty | Input Predictor |
# | age_of_casualty | Numeric | Age of the pedestrian casualty in years | Input Predictor |
# | pedestrian_location | Categorical | Pedestrian's location relative to the carriageway or crossing at collision | Input Predictor |
# | pedestrian_movement | Categorical | Reported movement of the pedestrian at collision | Input Predictor |
# | pedestrian_road_maintenance_worker | Categorical | Record as a road maintenance worker | Input Predictor |
# | casualty_imd_decile | Categorical | Index of Multiple Deprivation decile associated with the area of casualty| Input Predictor |
# | lsoa_of_accident_location | ID | LSOA code of the collision location | Retained for spatial exploratory analysis purposes, will be excluded from modelling |
# | longitude | Numeric | Longitude coordinate of the collision location | Retained in dataframe; excluded from modelling |
# | latitude | Numeric | Latitude coordinate of the collision location | Spatial Input Predictor |
# | speed_limit | Categorical | Speed limit of the collision location | Input Predictor |
# | first_road_class | Categorical | Classification of the first road at the collision location | Input Predictor |
# | road_type | Categorical | Type of road where the collision occurred | Input Predictor |
# | junction_detail | Categorical | Type of junction at the collision location | Input Predictor |
# | junction_control | Categorical | Tyoe of traffic control present at the junction | Input Predictor |
# | pedestrian_crossing | Categorical | Type of pedestrian crossing facility present | Input Predictor |
# | light_conditions | Categorical | Lighting conditions at collision | Input Predictor |
# | weather_conditions | Categorical | Weather conditions at collision | Input Predictor |
# | road_surface_conditions | Categorical | Condition of the road surface at the time of collision | Input Predictor |
# | urban_or_rural_area | Categorical | Classification of the collision location as urban or rural | Input Predictor |
# | trunk_road_flag | Categorical | Indicator of if the collision occurred on a trunk road | Input Predictor |
# | vehicle_type | Categorical | Type of vehicle associated with the pedestrian casualty | Input Predictor |
# | vehicle_manoeuvre | Categorical | Manoeuvre of the associated vehicle at collision | Input Predictor |
# | junction_location | Categorical | Position of the associated vehicle relative to the junction | Input Predictor |
# | dist_to_greenspace_m | Numeric | Distance to the nearest greenspace access point in metres | Spatial Input Predictor, typically for answering RQ2 |

# %% [markdown]
# ## 4. Methodology
#
# [[ go back to the top ]](#Table-of-contents)
#
# - 4.1. Exploratory Analysis
# - 4.2. Decision Tree (Baseline Model)
# - 4.3. Random Forest (Models with and without Greenspace variable)
# - 4.4. Model Comparison and Interpretation (Optimal Model and SHAP model interpretation)
#
# Machine learning (ML) approaches has been widely adopted in road safety data analysis, as traditional discrete methods depend on pre-specified assumptions and tends to struggle with noisy data. ML benefits from higher flexibility, ability to acquire only minimal prior assumptions, thus demonstrate stronger predictive (Dong et al., 2022; Tao et al., 2022). While ML approaches can establish complex, non-linear relationships between input variables and injury severity outcomes, yet it also face limitations of their black-box nature (Dong et al., 2022). Therefore, this analysis applies two tree-based ensemble models and a Shapley Additive exPlanations (SHAP) to rank feature importance and interpret the optimal model from a global perspective.

# %%
# methodology flowchart requirements:
# Source: see [link](https://linkinghub.elsevier.com/retrieve/pii/S2210670722004437).

# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.1. Exploratory Analysis

# %% [markdown]
# ### Distribution of Pedestrian Injury Severity

# %%
import matplotlib.pyplot as plt
import numpy as np

severity_counts = df_clean['severity_levels'].value_counts()
labels = ['Slight (0)', 'Fatal/Serious (1)']
colors = ['#2B6CB0', '#C81E2A']

fig, ax = plt.subplots(figsize=(6, 4))
bars = ax.bar(labels, severity_counts.values, color=colors, edgecolor='white', width=0.5)

for bar, count in zip(bars, severity_counts.values):
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() + 30,
            f'{count}\n({count/len(df_clean)*100:.1f}%)',
            ha='center', va='bottom', fontsize=11)

ax.set_title('Distribution of Pedestrian Injury Severity', fontsize=13)
ax.set_ylabel('Number of Casualties')
ax.set_ylim(0, severity_counts.max() * 1.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# A structural challenge common to road collision datasets is class imbalance. In this analytical sample, fatal and serious casualties account for approximately 26.9% of observations, with slight injuries comprising the remaining 73.1%. An unweighted classifier trained on this data would be biased toward predicting the majority class, which will result will poorly perform on the events for greatest safety relevance. To address this, class weighting was applied in both models, assigning a higher penalty to misclassification of the minority fatal/serious class.
# Recall was therefore prioritised as the primary evaluation metric over accuracy. In a road safety context, failing to identify a genuinely severe outcome carries a greater real-world cost than generating a false positive, a model that misses fatal collisions is more dangerous than one that occasionally over-predicts severity.

# %% [markdown]
# ### Pedestrian Injury Severity by Speed Limit

# %%
speed_order_filtered = ['20', '30', '40']

speed_df = df_clean[df_clean['speed_limit'].notna()].copy()
speed_df['speed_limit'] = speed_df['speed_limit'].astype(str).str.replace('.0', '', regex=False)
speed_df = speed_df[speed_df['speed_limit'].isin(speed_order_filtered)]

speed_agg = (
    speed_df.groupby(['speed_limit', 'severity_levels'])
    .size()
    .unstack(fill_value=0)
    .reindex(speed_order_filtered)
)
speed_pct = speed_agg.div(speed_agg.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(9, 5))

x = np.arange(len(speed_order_filtered))
width = 0.35

bars1 = ax.bar(x - width/2, speed_pct[0], width,
               label='Slight', color='#2B6CB0',
               edgecolor='white')

bars2 = ax.bar(x + width/2, speed_pct[1], width,
               label='Fatal / Serious', color='#C81E2A',
               edgecolor='white')

# Add sample size below x axis labels
speed_counts = speed_agg.sum(axis=1).values
xtick_labels = [f'{s}mph\n(n={n:,})' for s, n in zip(speed_order_filtered, speed_counts)]

ax.set_xticks(x)
ax.set_xticklabels(xtick_labels)
ax.set_ylim(0, 100)
ax.set_title('Pedestrian Injury Severity by Speed Limit',
             fontsize=13)
ax.set_xlabel('Speed Limit')
ax.set_ylabel('Percentage of Casualties (%)')
ax.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Percentage of Fatal and Serious Injury Severity Level by Age Group

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import pandas as pd

age_bins   = [0, 10, 17, 25, 35, 45, 55, 65, 75, 100]
age_labels = ['0-9', '10-17', '18-25', '26-35', '36-45', '46-55', '56-65', '66-75', '76+']

age_df = df_clean[df_clean['age_of_casualty'].notna()].copy()
age_df['age_group'] = pd.cut(
    age_df['age_of_casualty'],
    bins=age_bins,
    labels=age_labels,
    right=False
)

age_agg = (
    age_df.groupby(['age_group', 'severity_levels'], observed=True)
    .size()
    .unstack(fill_value=0)
)
age_pct = age_agg.div(age_agg.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(10, 5))

bars = ax.bar(
    age_labels,
    age_pct[1],
    color='#C81E2A',
    edgecolor='white',
    width=0.7
)

ax.set_title('Percentage of Fatal or Serious by Age Group', fontsize=13)
ax.set_xlabel('Age Group')
ax.set_ylabel('Percentage of Fatal or Serious')
ax.set_xticklabels(age_labels, rotation=45, ha='right')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distance to Nearest Greenspace Access Point by Severity Level

# %%
fig, ax = plt.subplots(figsize=(7, 5))

data = [
    df_clean[df_clean['severity_levels'] == 0]['dist_to_greenspace_m'].dropna(),
    df_clean[df_clean['severity_levels'] == 1]['dist_to_greenspace_m'].dropna()
]

bp = ax.boxplot(
    data,
    labels=['Slight', 'Fatal / Serious'],
    patch_artist=True,
    boxprops=dict(facecolor='#D0E8FF', color='#2B6CB0'),
    medianprops=dict(color='#C81E2A', linewidth=2.5),
    whiskerprops=dict(color='#2B6CB0'),
    capprops=dict(color='#2B6CB0'),
    flierprops=dict(marker='o', markerfacecolor='grey', markersize=3, alpha=0.3)
)

# Colour fatal/serious box differently
bp['boxes'][1].set_facecolor('#FFD0D0')
bp['boxes'][1].set_edgecolor('#C81E2A')
bp['whiskers'][2].set_color('#C81E2A')
bp['whiskers'][3].set_color('#C81E2A')
bp['caps'][2].set_color('#C81E2A')
bp['caps'][3].set_color('#C81E2A')

ax.set_title(
    'Distance to Nearest Greenspace Access Point by Severity Level in London in 2024',
    fontsize=13
)
ax.set_ylabel('Distance to Nearest Greenspace (metres)')
plt.tight_layout()
plt.show()

# %%
# lsoa_pop = pd.read_excel(
#     'sapelsoasyoa20222024.xlsx',
#     sheet_name='Mid-2024 LSOA 2021',
#     skiprows=4
# )

# # Get LSOA code and total population by column index
# pop = lsoa_pop.iloc[:, [2, 4]].copy()
# pop.columns = ['LSOA11CD', 'population']

# # Filter to London LSOAs only
# pop_london = pop[pop['LSOA11CD'].str.startswith('E01')].copy()
# pop_london['population'] = pd.to_numeric(pop_london['population'], errors='coerce')


# Aggregate severity by LSOA
lsoa_severity = (
    df_clean.groupby('lsoa_of_accident_location')['severity_levels']
    .agg(
        total_collisions='count',
        fatal_serious='sum'
    )
    .reset_index()
    .rename(columns={'lsoa_of_accident_location': 'LSOA11CD'})
)


# Merge boundary, severity, population estimates
lsoa_map = london_lsoa.merge(
    lsoa_severity,
    on='LSOA11CD',
    how='left'
)
lsoa_map = lsoa_map.merge(
    london_lsoa_pop,
    on='LSOA11CD',
    how='left'
)


# Calculate rate per 10,000 residents
lsoa_map['rate_per_10000'] = (
    lsoa_map['fatal_serious'] / lsoa_map['population'] * 10_000
).round(2)

# Plot map
fig, ax = plt.subplots(figsize=(14, 10))

# London LSOA
lsoa_map[lsoa_map['rate_per_10000'].isna()].plot(
    ax=ax,
    color='#f5f5f5',
    edgecolor='white',
    linewidth=0.3
)
# Fatal or serious
lsoa_map[lsoa_map['rate_per_10000'].notna()].plot(
    column='rate_per_10000',
    ax=ax,
    cmap='Reds',
    edgecolor='white',
    linewidth=0.3,
    legend=True,
    legend_kwds={
        'label': 'Fatal/Serious Pedestrian Casualties per 10,000 Population',
        'orientation': 'vertical',
        'shrink': 0.6
    }
)

ax.set_title(
    'Fatal or Serious Pedestrian Casualty Rate per 10,000 Population by London LSOAs in 2024',
    fontsize=14, pad=15
)
ax.set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2. Decision Tree

# %%
X = df_clean[numeric_features + categorical_features].copy()
y = df_clean['severity_levels'].copy()

X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval,
    test_size=0.25,   # 25% of 80% = 20% validation
    random_state=42,
    stratify=y_trainval
)

# %%
# Decision Tree pipeline
dt_pipeline = Pipeline(steps=[
    ('transformed', transformed),
    ('model', DecisionTreeClassifier(random_state=42))
])

# Grid
param_grid_dt = {
    'model__max_depth': [3, 5, 10, 15, 20, None],
    'model__min_samples_split': [5, 10, 20],
    'model__min_samples_leaf': [1, 2, 4, 8],
    'model__criterion': ['gini', 'entropy'],
    'model__class_weight': ['balanced', {0: 1, 1: 2}, {0: 1, 1: 3}]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_dt = GridSearchCV(
    estimator=dt_pipeline,
    param_grid=param_grid_dt,
    scoring='f1',
    cv=cv,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_dt.fit(X_train, y_train)

best_dt = grid_dt.best_estimator_

print("\nBest Decision Tree hyperparameters:")
print(grid_dt.best_params_)
print(f"\nBest cross-validated F1 on training set: {grid_dt.best_score_:.4f}")

# Threshold tuning
val_probs_dt = best_dt.predict_proba(X_val)[:, 1]

thresholds_dt = np.arange(0.10, 0.91, 0.05)
threshold_rows_dt = []

for th in thresholds_dt:
    val_pred_dt = (val_probs_dt >= th).astype(int)
    threshold_rows_dt.append({
        'threshold': th,
        'precision': precision_score(y_val, val_pred_dt, zero_division=0),
        'recall': recall_score(y_val, val_pred_dt, zero_division=0),
        'f1': f1_score(y_val, val_pred_dt, zero_division=0)
    })

threshold_df_dt = pd.DataFrame(threshold_rows_dt).sort_values('f1', ascending=False)
best_threshold_dt = threshold_df_dt.iloc[0]['threshold']

print(f"\nSelected threshold based on validation F1: {best_threshold_dt:.2f}")
print(threshold_df_dt.head())

# Refit on train validation
best_dt.fit(X_trainval, y_trainval)



# Test evaluation
test_probs_dt = best_dt.predict_proba(X_test)[:, 1]
test_pred_dt = (test_probs_dt >= best_threshold_dt).astype(int)

test_accuracy_dt = accuracy_score(y_test, test_pred_dt)
test_precision_dt = precision_score(y_test, test_pred_dt, zero_division=0)
test_recall_dt = recall_score(y_test, test_pred_dt, zero_division=0)
test_f1_dt = f1_score(y_test, test_pred_dt, zero_division=0)
test_roc_auc_dt = roc_auc_score(y_test, test_probs_dt)
test_pr_auc_dt = average_precision_score(y_test, test_probs_dt)

print("\nDecision Tree Test Results")
print(f"Accuracy : {test_accuracy_dt:.4f}")
print(f"Precision: {test_precision_dt:.4f}")
print(f"Recall   : {test_recall_dt:.4f}")
print(f"F1-score : {test_f1_dt:.4f}")
print(f"ROC-AUC  : {test_roc_auc_dt:.4f}")
print(f"PR-AUC   : {test_pr_auc_dt:.4f}\n")

print("Decision Tree Classification report:")
print(classification_report(
    y_test,
    test_pred_dt,
    target_names=['Slight', 'Fatal/ Serious']
))

dt_results = {
    # 'Train_Share': X_train.shape[0] / len(X),
    # 'Validation_Share': X_val.shape[0] / len(X),
    # 'Test_Share': X_test.shape[0] / len(X),
    # 'Best_CV_F1': grid_dt.best_score_,
    # 'Best_Threshold': best_threshold_dt,
    'Test_Accuracy': test_accuracy_dt,
    'Test_Precision': test_precision_dt,
    'Test_Recall': test_recall_dt,
    'Test_F1': test_f1_dt,
    'Test_ROC_AUC': test_roc_auc_dt,
    'Test_PR_AUC': test_pr_auc_dt
}

print(dt_results)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
#
# Best Decision Tree hyperparameters:
# {'model__class_weight': 'balanced', 'model__criterion': 'gini', 'model__max_depth': 5, 'model__min_samples_leaf': 8, 'model__min_samples_split': 20}
#
# Best cross-validated F1 on training set: 0.4673
#
# Selected threshold based on validation F1: 0.50
#    threshold  precision    recall        f1
# 8       0.50   0.378866  0.615063  0.468900
# 5       0.35   0.311874  0.912134  0.464819
# 9       0.55   0.376623  0.606695  0.464744
# 6       0.40   0.321370  0.824268  0.462441
# 4       0.30   0.309659  0.912134  0.462354
#
# Decision Tree Test Results
# Accuracy : 0.5534
# Precision: 0.3433
# Recall   : 0.7238
# F1-score : 0.4657
# ROC-AUC  : 0.6396
# PR-AUC   : 0.3710
#
# Decision Tree Classification report:
#                 precision    recall  f1-score   support
#
#         Slight       0.83      0.49      0.62       650
# ...

# %% [markdown]
# ## 4.3. Random Forest

# %% [markdown]
# ### 4.3.1. Random Forest Calibration

# %%
from sklearn.calibration import CalibratedClassifierCV

X = df_clean[numeric_features + categorical_features].copy()
y = df_clean['severity_levels'].copy()

# Train Test Split
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval,
    test_size=0.25,   # 25% of 80% = 20% of full data
    random_state=42,
    stratify=y_trainval
)

print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)

# Random Forest pipeline
rf_pipeline = Pipeline(steps=[
    ('transformed', transformed),
    ('model', RandomForestClassifier(
        random_state=42,
        n_jobs=-1
    ))
])

# Hyperparameter grid
param_grid_rf = {
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [5, 10, 15, None],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['sqrt', 'log2'],
    'model__class_weight': ['balanced', {0: 1, 1: 2}, {0: 1, 1: 3}]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_rf = GridSearchCV(
    estimator=rf_pipeline,
    param_grid=param_grid_rf,
    scoring='f1',
    cv=cv,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_rf.fit(X_train, y_train)
best_rf = grid_rf.best_estimator_

print("\nBest hyperparameters:")
print(grid_rf.best_params_)
print(f"\nBest cross-validated F1 in training: {grid_rf.best_score_:.4f}")

# Calibration
calibrated_rf = CalibratedClassifierCV(
    estimator=best_rf,
    method='isotonic',
    cv=5
)
calibrated_rf.fit(X_train, y_train)
print("\nProbability calibration applied (isotonic, cv=5)")

# Threshold tuning on calibrated probabilities
val_probs_rf = calibrated_rf.predict_proba(X_val)[:, 1]

thresholds_rf = np.arange(0.10, 0.91, 0.05)
threshold_rows_rf = []

for th in thresholds_rf:
    val_pred_rf = (val_probs_rf >= th).astype(int)
    threshold_rows_rf.append({
        'threshold': th,
        'precision': precision_score(y_val, val_pred_rf, zero_division=0),
        'recall':    recall_score(y_val, val_pred_rf, zero_division=0),
        'f1':        f1_score(y_val, val_pred_rf, zero_division=0)
    })

threshold_df_rf = pd.DataFrame(threshold_rows_rf).sort_values('f1', ascending=False)
best_threshold_rf = threshold_df_rf.iloc[0]['threshold']

print(f"\nBest threshold from validation F1: {best_threshold_rf:.2f}")
print(threshold_df_rf.head())

# Refit calibrated model on full trainval
calibrated_rf.fit(X_trainval, y_trainval)

# Test evaluation
test_probs_rf = calibrated_rf.predict_proba(X_test)[:, 1]
test_pred_rf  = (test_probs_rf >= best_threshold_rf).astype(int)

test_accuracy_rf  = accuracy_score(y_test, test_pred_rf)
test_precision_rf = precision_score(y_test, test_pred_rf, zero_division=0)
test_recall_rf    = recall_score(y_test, test_pred_rf, zero_division=0)
test_f1_rf        = f1_score(y_test, test_pred_rf, zero_division=0)
test_roc_auc_rf   = roc_auc_score(y_test, test_probs_rf)
test_pr_auc_rf    = average_precision_score(y_test, test_probs_rf)

print("\nRandom Forest (Calibrated) Test Results")
print(f"Accuracy : {test_accuracy_rf:.4f}")
print(f"Precision: {test_precision_rf:.4f}")
print(f"Recall   : {test_recall_rf:.4f}")
print(f"F1-score : {test_f1_rf:.4f}")
print(f"ROC-AUC  : {test_roc_auc_rf:.4f}")
print(f"PR-AUC   : {test_pr_auc_rf:.4f}\n")

print("Random Forest (Calibrated) Classification report:")
print(classification_report(
    y_test,
    test_pred_rf,
    target_names=['Slight', 'Fatal/ Serious']
))

rf_results = {
    'Test_Accuracy':  test_accuracy_rf,
    'Test_Precision': test_precision_rf,
    'Test_Recall':    test_recall_rf,
    'Test_F1':        test_f1_rf,
    'Test_ROC_AUC':   test_roc_auc_rf,
    'Test_PR_AUC':    test_pr_auc_rf
}
# Out:
# Train: (2667, 21) (2667,)
# Validation: (889, 21) (889,)
# Test: (889, 21) (889,)
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#
# Best hyperparameters:
# {'model__class_weight': {0: 1, 1: 3}, 'model__max_depth': 5, 'model__max_features': 'log2', 'model__min_samples_leaf': 4, 'model__n_estimators': 300}
#
# Best cross-validated F1 in training: 0.4701
#
# Probability calibration applied (isotonic, cv=5)
#
# Best threshold from validation F1: 0.30
#    threshold  precision    recall        f1
# 4       0.30   0.447205  0.602510  0.513369
# 3       0.25   0.385321  0.702929  0.497778
# 2       0.20   0.311747  0.866109  0.458472
# 5       0.35   0.456067  0.456067  0.456067
# 1       0.15   0.297554  0.916318  0.449231
#
# Random Forest (Calibrated) Test Results
# Accuracy : 0.6682
# Precision: 0.4181
# Recall   : 0.5983
# F1-score : 0.4923
# ROC-AUC  : 0.6820
# PR-AUC   : 0.4360
#
# Random Forest (Calibrated) Classification report:
# ...

# %% [markdown]
# ### 4.3.2. Random Forest without Greenspace Variable Calibration

# %%
from sklearn.calibration import CalibratedClassifierCV

# Define feature set without greenspace
numeric_features_rf2 = [
    'age_of_casualty'
]

categorical_features_rf2 = [
    'sex_of_casualty',
    'pedestrian_location',
    'pedestrian_movement',
    'pedestrian_road_maintenance_worker',
    'casualty_imd_decile',
    'speed_limit',
    'first_road_class',
    'road_type',
    'junction_detail',
    'junction_control',
    'pedestrian_crossing',
    'light_conditions',
    'weather_conditions',
    'road_surface_conditions',
    'urban_or_rural_area',
    'trunk_road_flag',
    'vehicle_type',
    'vehicle_manoeuvre',
    'junction_location'
]

# Keep only columns that actually exist
numeric_features_rf2 = [col for col in numeric_features_rf2 if col in df_clean.columns]
categorical_features_rf2 = [col for col in categorical_features_rf2 if col in df_clean.columns]

# Build X and y
X_rf2 = df_clean[numeric_features_rf2 + categorical_features_rf2].copy()
y_rf2 = df_clean['severity_levels'].copy()

print("X_rf2 shape:", X_rf2.shape)
print("y_rf2 distribution:")
print(y_rf2.value_counts())
print(y_rf2.value_counts(normalize=True).round(3))

# Train / validation / test split
X_trainval_rf2, X_test_rf2, y_trainval_rf2, y_test_rf2 = train_test_split(
    X_rf2, y_rf2,
    test_size=0.20,
    random_state=42,
    stratify=y_rf2
)

X_train_rf2, X_val_rf2, y_train_rf2, y_val_rf2 = train_test_split(
    X_trainval_rf2, y_trainval_rf2,
    test_size=0.25,
    random_state=42,
    stratify=y_trainval_rf2
)

print("Train:", X_train_rf2.shape, y_train_rf2.shape)
print("Validation:", X_val_rf2.shape, y_val_rf2.shape)
print("Test:", X_test_rf2.shape, y_test_rf2.shape)

# Preprocessing pipeline for rf2
numeric_pipeline_rf2 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_pipeline_rf2 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

transformed_rf2 = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline_rf2, numeric_features_rf2),
        ('cat', categorical_pipeline_rf2, categorical_features_rf2)
    ]
)

# Random forest pipeline
rf2_pipeline = Pipeline(steps=[
    ('transformed', transformed_rf2),
    ('model', RandomForestClassifier(
        random_state=42,
        n_jobs=-1
    ))
])

# Same parameter grid as calibrated rf
param_grid_rf2 = {
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [5, 10, 15, None],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['sqrt', 'log2'],
    'model__class_weight': ['balanced', {0: 1, 1: 2}, {0: 1, 1: 3}]
}

cv_rf2 = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_rf2 = GridSearchCV(
    estimator=rf2_pipeline,
    param_grid=param_grid_rf2,
    scoring='f1',
    cv=cv_rf2,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_rf2.fit(X_train_rf2, y_train_rf2)
best_rf2 = grid_rf2.best_estimator_

print("\nBest rf2 hyperparameters:")
print(grid_rf2.best_params_)
print(f"\nBest cross-validated F1 in training (rf2): {grid_rf2.best_score_:.4f}")

# Calibration
calibrated_rf2 = CalibratedClassifierCV(
    estimator=best_rf2,
    method='isotonic',
    cv=5
)
calibrated_rf2.fit(X_train_rf2, y_train_rf2)
print("\nProbability calibration applied (isotonic, cv=5)")

# Threshold tuning on CALIBRATED probabilities
val_probs_rf2 = calibrated_rf2.predict_proba(X_val_rf2)[:, 1]

thresholds_rf2 = np.arange(0.10, 0.91, 0.05)
threshold_rows_rf2 = []

for th in thresholds_rf2:
    val_pred_rf2 = (val_probs_rf2 >= th).astype(int)
    threshold_rows_rf2.append({
        'threshold': th,
        'precision': precision_score(y_val_rf2, val_pred_rf2, zero_division=0),
        'recall':    recall_score(y_val_rf2, val_pred_rf2, zero_division=0),
        'f1':        f1_score(y_val_rf2, val_pred_rf2, zero_division=0)
    })

threshold_df_rf2 = pd.DataFrame(threshold_rows_rf2).sort_values('f1', ascending=False)
best_threshold_rf2 = threshold_df_rf2.iloc[0]['threshold']

print(f"\nBest threshold from validation F1: {best_threshold_rf2:.2f}")
print(threshold_df_rf2.head())

# Refit calibrated model on full trainval
calibrated_rf2.fit(X_trainval_rf2, y_trainval_rf2)

# Test evaluation
test_probs_rf2 = calibrated_rf2.predict_proba(X_test_rf2)[:, 1]
test_pred_rf2  = (test_probs_rf2 >= best_threshold_rf2).astype(int)

test_accuracy_rf2  = accuracy_score(y_test_rf2, test_pred_rf2)
test_precision_rf2 = precision_score(y_test_rf2, test_pred_rf2, zero_division=0)
test_recall_rf2    = recall_score(y_test_rf2, test_pred_rf2, zero_division=0)
test_f1_rf2        = f1_score(y_test_rf2, test_pred_rf2, zero_division=0)
test_roc_auc_rf2   = roc_auc_score(y_test_rf2, test_probs_rf2)
test_pr_auc_rf2    = average_precision_score(y_test_rf2, test_probs_rf2)

print("\nRandom Forest (Calibrated) without Greenspace Test Results")
print(f"Accuracy : {test_accuracy_rf2:.4f}")
print(f"Precision: {test_precision_rf2:.4f}")
print(f"Recall   : {test_recall_rf2:.4f}")
print(f"F1-score : {test_f1_rf2:.4f}")
print(f"ROC-AUC  : {test_roc_auc_rf2:.4f}")
print(f"PR-AUC   : {test_pr_auc_rf2:.4f}\n")

print("Random Forest (Calibrated) without Greenspace Classification report:")
print(classification_report(
    y_test_rf2,
    test_pred_rf2,
    target_names=['Slight', 'Fatal/ Serious']
))

# Save results
rf2_results = {
    'Test_Accuracy':  test_accuracy_rf2,
    'Test_Precision': test_precision_rf2,
    'Test_Recall':    test_recall_rf2,
    'Test_F1':        test_f1_rf2,
    'Test_ROC_AUC':   test_roc_auc_rf2,
    'Test_PR_AUC':    test_pr_auc_rf2
}

print("\nrf2_results:")
print(rf2_results)
# Out:
# X_rf2 shape: (4445, 20)
# y_rf2 distribution:
# severity_levels
# 0    3249
# 1    1196
# Name: count, dtype: int64
# severity_levels
# 0    0.731
# 1    0.269
# Name: proportion, dtype: float64
# Train: (2667, 20) (2667,)
# Validation: (889, 20) (889,)
# Test: (889, 20) (889,)
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
#
# Best rf2 hyperparameters:
# {'model__class_weight': 'balanced', 'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__n_estimators': 200}
#
# Best cross-validated F1 in training (rf2): 0.4695
#
# Probability calibration applied (isotonic, cv=5)
#
# Best threshold from validation F1: 0.30
#    threshold  precision    recall        f1
# 4       0.30   0.445161  0.577406  0.502732
# 3       0.25   0.390995  0.690377  0.499244
# 5       0.35   0.477679  0.447699  0.462203
# 2       0.20   0.308605  0.870293  0.455641
# 1       0.15   0.299040  0.912134  0.450413
#
# ...

# %% [markdown]
# ## 4.4. Model Comparison and Interpretation
# ### 4.4.1. Model Comparison

# %%
import pandas as pd
results_df = pd.DataFrame({
  'Decision Tree': dt_results,
  'Random Forest (Calibrated)': rf_results,
  'Random Forest without Greenspace (Calibrated)': rf2_results
}).T
print(results_df.round(3))
# Out:
#                                                Test_Accuracy  Test_Precision  \
# Decision Tree                                          0.553           0.343
# Random Forest (Calibrated)                             0.668           0.418
# Random Forest without Greenspace (Calibrated)          0.674           0.421
#
#                                                Test_Recall  Test_F1  \
# Decision Tree                                        0.724    0.466
# Random Forest (Calibrated)                           0.598    0.492
# Random Forest without Greenspace (Calibrated)        0.565    0.482
#
#                                                Test_ROC_AUC  Test_PR_AUC
# Decision Tree                                         0.640        0.371
# Random Forest (Calibrated)                            0.682        0.436
# Random Forest without Greenspace (Calibrated)         0.680        0.435

# %% [markdown]
# The Random Forest outperformed the Decision Tree across most evaluation metrics. Although the Decision Tree achieved slightly higher recall for fatal or serious pedestrian outcomes, the calibrated Random Forest produced better overall classification performance. This suggests that the calibrated Random Forest provided a better balance between identifying severe cases and reducing false positives, and was therefore selected as the preferred model for interpretation.
#
# Greenspace proximity contributes marginal but consistent predictive value, improving PR-AUC by ... and recall by ... percentage points, suggesting it captures some spatial context not fully explained by road and collision characteristics alone. However the improvement is too small to justify greenspace accessibility as a primary policy lever for severity reduction.

# %% [markdown]
# ### 4.4.2. SHAP Model Interpretation

# %%
import shap
import numpy as np

# for faster plotting, sample test data
X_test_sample = X_test.sample(n=min(500, len(X_test)), random_state=42)

# use the fitted preprocessing step and fitted RF from your best pipeline
preprocessor = best_rf.named_steps['transformed']
rf_model = best_rf.named_steps['model']

# transform test data into the same format seen by the RF
X_test_sample_transformed = preprocessor.transform(X_test_sample)

# convert sparse matrix to dense if needed
if hasattr(X_test_sample_transformed, "toarray"):
    X_test_sample_transformed = X_test_sample_transformed.toarray()

# force numeric dtype
X_test_sample_transformed = np.asarray(X_test_sample_transformed, dtype=np.float64)

# get transformed feature names
feature_names = preprocessor.get_feature_names_out()
feature_names = [f.replace("num__", "").replace("cat__", "") for f in feature_names]

# SHAP explainer
explainer = shap.TreeExplainer(rf_model)
shap_values = explainer(X_test_sample_transformed)

# keep class 1 = fatal/serious
shap_values_class1 = shap.Explanation(
    values=shap_values.values[:, :, 1],
    base_values=shap_values.base_values[:, 1],
    data=shap_values.data,
    feature_names=feature_names
)

# %% [markdown]
# Greenspace accessibility contributed lightly on explanatory value for severe pedestrian injury when pedestrian, road, collision, vehicle factors were accounted for. SHAP analysis identified casualty age, junction-related variables, vehicle manoeuvre, driver characteristics, and road context as the primary predictors. Distance to the nearest greenspace access point was retained in the final random forest model but carried a low mean absolute SHAP value of ..., indicating that it contributes relatively less in comparison to the characteristics of the collision environment and individuals involved.

# %%
# Group dummies into original variables for SHAP interpretation

# Define original variable 
all_original_features = numeric_features + categorical_features

# Get all feature names and their corresponding SHAP values
feat_names = list(shap_values_class1.feature_names)
shap_vals  = shap_values_class1.values

# Group dummy columns to original variables
grouped_shap = np.zeros((shap_vals.shape[0], len(all_original_features)))
grouped_data = np.zeros((shap_vals.shape[0], len(all_original_features)))

for col_idx, orig in enumerate(all_original_features):
    if orig in numeric_features:
        if orig in feat_names:
            i = feat_names.index(orig)
            grouped_shap[:, col_idx] = shap_vals[:, i]
            grouped_data[:, col_idx] = shap_values_class1.data[:, i]
    else:
        indices = [i for i, name in enumerate(feat_names)
                   if name.startswith(orig + '_') or name == orig]
        if indices:
            grouped_shap[:, col_idx] = shap_vals[:, indices].sum(axis=1)
            grouped_data[:, col_idx] = np.abs(shap_vals[:, indices]).sum(axis=1)

# Rebuild grouped Explanation object
grouped_explanation = shap.Explanation(
    values        = grouped_shap,
    base_values   = shap_values_class1.base_values,
    data          = grouped_data,
    feature_names = all_original_features
)

# %%
# Beeswarm plot with GROUPED original feature names (not encoded dummies)
shap.plots.beeswarm(grouped_explanation, max_display=20, show=False)
plt.title("SHAP Feature Importance for Fatal and Serious Severity Level",
          fontsize=13, pad=12)
plt.tight_layout()
plt.show()

# %%
# Plots summary stats
ranked = pd.Series(
    np.abs(grouped_explanation.values).mean(axis=0),
    index=all_original_features
).sort_values(ascending=False)

print("All features ranked by mean absolute SHAP:")
print(ranked.round(5).to_string())
# Out:
# All features ranked by mean absolute SHAP:
# vehicle_manoeuvre                     0.02314
# junction_location                     0.02077
# age_of_casualty                       0.01744
# road_type                             0.00740
# junction_detail                       0.00527
# light_conditions                      0.00456
# speed_limit                           0.00446
# pedestrian_location                   0.00425
# pedestrian_movement                   0.00375
# vehicle_type                          0.00341
# first_road_class                      0.00328
# pedestrian_crossing                   0.00326
# dist_to_greenspace_m                  0.00306
# junction_control                      0.00289
# weather_conditions                    0.00202
# sex_of_casualty                       0.00139
# casualty_imd_decile                   0.00132
# road_surface_conditions               0.00103
# pedestrian_road_maintenance_worker    0.00047
# ...

# %% [markdown]
# ## 5. Results and discussion
#
# [[ go back to the top ]](#Table-of-contents)

# %%
# Run these to get your numbers
print(f"Greenspace SHAP mean: {ranked['dist_to_greenspace_m']:.5f}")
print(f"RF with greenspace PR-AUC: {test_pr_auc_rf:.3f}")
print(f"RF without greenspace PR-AUC: {test_pr_auc_rf2:.3f}")
print(f"PR-AUC difference: {test_pr_auc_rf - test_pr_auc_rf2:.3f}")
print(f"Best class weight RF: {grid_rf.best_params_['model__class_weight']}")
print(f"RF accuracy: {test_accuracy_rf:.3f}")
print(f"RF recall: {test_recall_rf:.3f}")
print(f"RF precision: {test_precision_rf:.3f}")
# Out:
# Greenspace SHAP mean: 0.00306
# RF with greenspace PR-AUC: 0.436
# RF without greenspace PR-AUC: 0.435
# PR-AUC difference: 0.001
# Best class weight RF: {0: 1, 1: 3}
# RF accuracy: 0.668
# RF recall: 0.598
# RF precision: 0.418

# %% [markdown]
# **Model Performance**
# A higher recall score also comes with a trade off of a lower precision score. The model achieved a 0.35 precision score, suggesting that the model may tend to over predict severity levels.
#
#
# The Random Forest classifier outperformed the Decision Tree baseline across all evaluation scores, achieving a test accuracy of ..., a recall of ..., an F1-score of ..., a ROC-AUC of ..., and a PR-AUC of ... for fatal/ serious severity levels. In comparison the Decision Tree classifier produced a ROC-AUC of 0.64 and a PR-AUC of ..., confirming that the ensemble approach provided meaningfully better discriminative power. This performance advantage is consistent with exisiting road safety studies.
#
# The Rome pedestrian crash study similarly identified Random Forest as the best-performing model among five classifiers, achieving the highest F1-score in distinguishing fatal from non-fatal pedestrian outcomes (Scarano et al., 2025).In a road safety context, recall is recognised as the more policy-relevant evaluation metric over accuracy or precision, because failing to identify a genuinely severe collision carries a far greater real-world cost than generating a false positive. The model's recall of ... means it successfully identifies ...% of actual fatal or serious pedestrian injuries in the test set, making it a viable screening tool for transport planners seeking to flag high-risk road configurations. This prioritisation of recall comes with an expected trade-off: the model achieved a precision of ..., indicating a tendency to over-predict severity. This is a deliberate consequence of applying class weighting of {...} to counteract the structural class imbalance in the dataset, where fatal and serious casualties represent only ...% of observations. Under an imbalanced classification setting, a model that is not penalised for missing the minority class will default to predicting the majority class almost exclusively, which would be analytically meaningless in a road safety context. The precision-recall trade-off observed here is therefore an expected and accepted outcome of the modelling strategy rather than a deficiency of the model. Similar trade-offs have been reported across the pedestrian injury severity literature when class weighting or oversampling techniques are applied to address the rarity of fatal outcomes (Abdel-Aty and Islam, 2025).The overall accuracy of ..., while modest in absolute terms, should be interpreted within the constraints of the dataset. The absence of contributory factors from the open STATS19 release, which capture officer-recorded behavioural causes such as driver inattention and excessive speed, is acknowledged to place a ceiling on the predictive performance achievable from open data alone. Studies using restricted-access STATS19 data with contributory factors consistently report higher model performance, suggesting that the behavioural dimension of collisions carries substantial explanatory weight not available here.
#
#
# **RQ1:** SHAP analysis from the weighted Random Forest identified the most featured importance predictors of pedestrian injury severity. Casualty age is found as the most influential variable, consistent with greater physiological vulnerability among older pedestrians, who are substantially more likely to acquire fatal or serious outcomes. Junction related variables of junction_detail and junction_location also ranked highly, reflecting that the presence of concentration of severe collisions at complex navigation points where vehicle movements may collide with pedestrian usages. Vehicle manoeuvre and vehicle type also carried meaningful explanatory weight, positioning the importance of collision physics in determining severity outcome. Driver-level demographic variables, including age_of_driver and sex_of_driver contributed additional explanatory value, suggesting that driver behaviour and reaction capacity are also relevant factors. Road environment variables, such as speed limit and pedestrian crossing type are featured in the at lower parts of the SHAP rankings, indicating a secondary but a substaintial structural influence on severity.
#
# **RQ2:** Distance to the nearest greenspace access point was preserved in the main Random Forest model as a spatial contextual variable. Its mean absolute SHAP value was found as ..., placing it at a lower position as a predictor in the model. Once pedestrian, junction, vehicle, and driver characteristics were accounted for, greenspace proximity contributed negligible additional explanatory value. This suggests that, within the analytical framework applied here, the immediate physical and human characteristics of the collision environment are far stronger determinants of injury severity than the surrounding spatial context.
#
# It is also important to recognise that several predictor variables, such as road class, speed limit, and junction-related features, are likely to exhibit multicollinearity. This may lead to SHAP interpretation to skew feature importance rankings by splitting attribution across correlated variables. However, this does not undermine the Random Forest model itself, as it makes decisions through splitting nodes which reduces the impact of multicollinearity on predictive performance. While the model remains robust in predictions, it is also important to note that there may still be a possibility that the individual contribution of certain road environment features may be slightly underestimated with SHAP.

# %% [markdown]
# ## 6. Conclusion
#
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# Pedestrian age and junction complexity were the most important predictors of severity levels, reflecting both biological vulnerability and structural risk of road users. The model achieved a recall of 78%, making it a viable screening tool for transport planners seeking to identify potentially lethal road configurations, accepting lower precision in exchange for greater sensitivity. Despite greenspace accessibility to be relevant to wider urban health outcomes, yet it did not emerge as a primary driver of injury severity when modelled against conventional traffic engineering factors.
#
# Critically, appplying machine learning algorithms in studying pedestrian collision remains a lack of interpretability. Often known as a "black box", there is limitations in understanding the role of each variable in predicting severity levels. Variable feature importance is evaluated with SHAP.
#
# These findings also has direct policy relevance, supporting the "Vision Zero" strategy in London's transport system, particularly speed reduction and improved junction visibility, especially in areas with higher concentrations of higher aged pedestrian road users, where such measures carry greater weight than wider environmental features in determining collision outcomes.
#
# Future research directions: can consider looking into unobserved factors such as a person's physical and mental health condition (https://www.sciencedirect.com/science/article/pii/S0001457508000985)

# %% [markdown]
# ## 7. References
#
# [[ go back to the top ]](#Table-of-contents)
